# %% [markdown]
# <a href="https://colab.research.google.com/github/filmerxyz/JSTP-22_SkinDiseaseClassificationUsingMachineLearning/blob/master/Accumulate_Classweight_DenseNet121_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Check GPU

# %%
# !nvidia-smi
# Out:
# Thu May 28 20:35:36 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Install Run:AI Gradient Accumulation library
# https://github.com/run-ai/runai/tree/master/runai/ga

# %%
# !pip install runai
# Out:
# Requirement already satisfied: runai in /usr/local/lib/python3.6/dist-packages (0.2.0)

# %% [markdown]
# # Import Libraries

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import pandas as pd
import numpy as np
import os
import math
import itertools
from PIL import Image
from matplotlib import pyplot as plt

import keras
from keras import backend as K
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from keras.regularizers import l2
from keras.models import Model, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import DenseNet121
from keras.legacy import interfaces
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import runai.ga.keras

from sklearn.model_selection import train_test_split
from sklearn.utils import compute_sample_weight, compute_class_weight
from sklearn.metrics import balanced_accuracy_score, classification_report, confusion_matrix

from ham10000_utils_functions import plot_confusion_matrix, normalize, deprocess_image, my_decode_predictions, guided_backprop, grad_cam, compute_saliency
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Hyperparameters

# %%
IMG_WIDTH = 224
IMG_HEIGHT = 224

BATCH_SIZE = 16
STEPS = 16
LR = 1e-4
EPOCHS = 100

# %% [markdown]
# # Data Preparation

# %%
# !git clone https://github.com/EvilPickle-PCSHSPT/ham10000-with-one-image-folder
# Out:
# fatal: destination path 'ham10000-with-one-image-folder' already exists and is not an empty directory.

# %%
metadata_path = '/content/ham10000-with-one-image-folder/HAM10000_metadata.csv'
img_path = '/content/ham10000-with-one-image-folder/HAM1000_images'

# %%
label_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# %%
data = pd.read_csv(metadata_path)

# %%
num_examples = data.values.shape[0]

# %%
inputs = np.empty(shape=(num_examples, IMG_WIDTH, IMG_HEIGHT, 3), dtype=np.float32)
labels = np.empty(shape=(num_examples), dtype=np.uint8)

# %% [markdown]
# ## Resize to 224*224

# %%
for i, row in enumerate(data.values):
    img_id = row[1]
    label = row[2]
    all_img_path = os.path.join(img_path, img_id) + '.jpg' 
    if (os.path.isfile(all_img_path)):
        im_path = all_img_path
    else:
        raise Exception ('File not found \'%s\'' %img_id)
    img = Image.open(im_path).resize((IMG_WIDTH, IMG_HEIGHT), Image.LANCZOS)
    inputs[i] = np.array(img)/255.0
    labels[i] = label_names.index(label)

# %% [markdown]
# ## Split Data

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs, labels, test_size=0.1, random_state=555)

del inputs
del labels

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.3, random_state=555)

# %%
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# (6309, 224, 224, 3) (6309,)
# (2704, 224, 224, 3) (2704,)
# (1002, 224, 224, 3) (1002,)

# %% [markdown]
# ## Data Augmentation

# %%
datagen = ImageDataGenerator(
        rotation_range=360,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='reflect')

# %%
datagen.fit(x_train)

# %% [markdown]
# # Adam Accumulate

# %%
ga_optimizer = runai.ga.keras.optimizers.Optimizer(Adam(LR), steps=STEPS)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# [Run:AI] [DEBUG   ] [28-05-2020 20:37:59.093] [1158] [optimizers.py          :16  ] Wrapping 'Adam' Keras optimizer with GA of 16 steps

# %% [markdown]
# # Build Model
# DenseNet121 + fine tuning

# %%
def build_model():
  base_model = DenseNet121(include_top=False, input_shape=(IMG_WIDTH, IMG_HEIGHT, 3), weights='imagenet')
  
  for layer in base_model.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False

  average_pooling_layer = GlobalAveragePooling2D()(base_model.output)
  
  fc_layer = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(average_pooling_layer)
  fc_layer = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(fc_layer)
  fc_layer = Dense(128, activation='relu', kernel_regularizer=l2(0.01))(fc_layer)
  fc_layer = Dense(64, activation='relu', kernel_regularizer=l2(0.01))(fc_layer)
  fc_layer = Dense(32, activation='relu', kernel_regularizer=l2(0.01))(fc_layer)
  bn_layer = BatchNormalization()(fc_layer)
  dropout_layer = Dropout(0.25)(bn_layer)
  prediction_layer = Dense(units=7, activation='softmax', name='prediction')(dropout_layer)

  model = Model(inputs=base_model.input, outputs=prediction_layer)

  model.compile(optimizer=ga_optimizer, 
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  return model

# %%
model = build_model()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.

# %%
# model.summary()

# %% [markdown]
# ## Class Weights

# %% [markdown]
# ### Train set

# %%
train_class_weight = compute_class_weight('balanced', np.unique(y_train), y_train)

# %%
print(train_class_weight)
# Out:
# [ 4.29183673  2.70656371  1.25527258 11.12698413  1.28571429  0.21587682
#   9.90423862]

# %%
train_class_weight_dict = { i : train_class_weight[i] for i in range(0, len(train_class_weight) ) }

# %% [markdown]
# ## Callbacks

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')

model_checkpoint = ModelCheckpoint(filepath='acc_densenet121_model.h5', save_best_only=True, monitor='val_loss', mode='min')

reduce_lr_rate = ReduceLROnPlateau(monitor='val_loss', factor=0.3, min_lr=1e-5 , patience=10, verbose=1, min_delta=1e-5, mode='min')

# %% [markdown]
# ## Training

# %%
history = model.fit_generator(datagen.flow(x_train, y_train, batch_size=BATCH_SIZE),
                              validation_data=(x_val, y_val, compute_sample_weight('balanced', y_val)),
                              class_weight=train_class_weight_dict,
                              steps_per_epoch=math.ceil(x_train.shape[0]/BATCH_SIZE),
                              epochs=EPOCHS,
                              callbacks=[early_stop, model_checkpoint, reduce_lr_rate])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/100
# 395/395 [==============================] - 101s 256ms/step - loss: 15.1284 - accuracy: 0.2324 - val_loss: 14.5420 - val_accuracy: 0.3066
# Epoch 2/100
# 395/395 [==============================] - 73s 186ms/step - loss: 14.2898 - accuracy: 0.3202 - val_loss: 13.8924 - val_accuracy: 0.3118
# Epoch 3/100
# 395/395 [==============================] - 73s 186ms/step - loss: 13.6814 - accuracy: 0.3455 - val_loss: 13.2418 - val_accuracy: 0.3964
# Epoch 4/100
# 395/395 [==============================] - 74s 187ms/step - loss: 13.0830 - accuracy: 0.3703 - val_loss: 12.7128 - val_accuracy: 0.4149
# Epoch 5/100
# 395/395 [==============================] - 74s 186ms/step - loss: 12.5636 - accuracy: 0.3590 - val_loss: 12.2147 - val_accuracy: 0.3798
# Epoch 6/100
# 395/395 [==============================] - 74s 186ms/step - loss: 12.0873 - accuracy: 0.3639 - val_loss: 11.7435 - val_accuracy: 0.4246
# Epoch 7/100
# 395/395 [==============================] - 73s 185ms/step - loss: 11.6385 - accuracy: 0.3799 - val_loss: 11.3472 - val_accuracy: 0.4161
# Epoch 8/100
# 395/395 [==============================] - 72s 183ms/step - loss: 11.2322 - accuracy: 0.3852 - val_loss: 10.9539 - val_accuracy: 0.4449
# Epoch 9/100
# 395/395 [==============================] - 71s 181ms/step - loss: 10.8926 - accuracy: 0.4055 - val_loss: 10.5880 - val_accuracy: 0.4183
# Epoch 10/100
# 395/395 [==============================] - 71s 180ms/step - loss: 10.5420 - accuracy: 0.4064 - val_loss: 10.2614 - val_accuracy: 0.4593
# Epoch 11/100
# 395/395 [==============================] - 72s 182ms/step - loss: 10.1719 - accuracy: 0.4215 - val_loss: 9.9394 - val_accuracy: 0.4438
# Epoch 12/100
# 395/395 [==============================] - 74s 188ms/step - loss: 9.8297 - accuracy: 0.4389 - val_loss: 9.6175 - val_accuracy: 0.4656
# Epoch 13/100
# 395/395 [==============================] - 74s 188ms/step - loss: 9.5889 - accuracy: 0.4221 - val_loss: 9.3543 - val_accuracy: 0.4708
# Epoch 14/100
# 395/395 [==============================] - 73s 185ms/step - loss: 9.2925 - accuracy: 0.4465 - val_loss: 9.1030 - val_accuracy: 0.4397
# Epoch 15/100
# 395/395 [==============================] - 73s 184ms/step - loss: 9.0422 - accuracy: 0.4519 - val_loss: 8.8237 - val_accuracy: 0.5192
# Epoch 16/100
# 395/395 [==============================] - 73s 185ms/step - loss: 8.8199 - accuracy: 0.4689 - val_loss: 8.5823 - val_accuracy: 0.5274
# Epoch 17/100
# 395/395 [==============================] - 74s 186ms/step - loss: 8.5624 - accuracy: 0.4687 - val_loss: 8.3719 - val_accuracy: 0.5274
# Epoch 18/100
# 395/395 [==============================] - 73s 185ms/step - loss: 8.3563 - accuracy: 0.4776 - val_loss: 8.1751 - val_accuracy: 0.5203
# Epoch 19/100
# 395/395 [==============================] - 72s 184ms/step - loss: 8.1498 - accuracy: 0.4779 - val_loss: 7.9949 - val_accuracy: 0.4926
# Epoch 20/100
# 395/395 [==============================] - 73s 184ms/step - loss: 7.9440 - accuracy: 0.4790 - val_loss: 7.7664 - val_accuracy: 0.5525
# Epoch 21/100
# 395/395 [==============================] - 73s 185ms/step - loss: 7.7196 - accuracy: 0.5055 - val_loss: 7.5999 - val_accuracy: 0.5226
# Epoch 22/100
# 395/395 [==============================] - 73s 185ms/step - loss: 7.5557 - accuracy: 0.5066 - val_loss: 7.4242 - val_accuracy: 0.5544
# Epoch 23/100
# 395/395 [==============================] - 73s 185ms/step - loss: 7.4254 - accuracy: 0.5202 - val_loss: 7.2734 - val_accuracy: 0.5392
# Epoch 24/100
# 395/395 [==============================] - 73s 185ms/step - loss: 7.2275 - accuracy: 0.5270 - val_loss: 7.1420 - val_accuracy: 0.5477
# Epoch 25/100
# 395/395 [==============================] - 74s 187ms/step - loss: 7.0747 - accuracy: 0.5311 - val_loss: 6.9962 - val_accuracy: 0.5950
# Epoch 26/100
# 395/395 [==============================] - 73s 185ms/step - loss: 6.9294 - accuracy: 0.5370 - val_loss: 6.7983 - val_accuracy: 0.5965
# Epoch 27/100
# 395/395 [==============================] - 72s 183ms/step - loss: 6.7609 - accuracy: 0.5565 - val_loss: 6.6940 - val_accuracy: 0.5721
# Epoch 28/100
# 395/395 [==============================] - 73s 184ms/step - loss: 6.6275 - accuracy: 0.5460 - val_loss: 6.5551 - val_accuracy: 0.5962
# Epoch 29/100
# 395/395 [==============================] - 73s 185ms/step - loss: 6.5002 - accuracy: 0.5640 - val_loss: 6.4170 - val_accuracy: 0.5962
# Epoch 30/100
# 395/395 [==============================] - 73s 185ms/step - loss: 6.3757 - accuracy: 0.5663 - val_loss: 6.3141 - val_accuracy: 0.5747
# Epoch 31/100
# 395/395 [==============================] - 73s 185ms/step - loss: 6.2735 - accuracy: 0.5579 - val_loss: 6.2051 - val_accuracy: 0.5629
# Epoch 32/100
# 395/395 [==============================] - 72s 182ms/step - loss: 6.1496 - accuracy: 0.5698 - val_loss: 6.1183 - val_accuracy: 0.5947
# Epoch 33/100
# 395/395 [==============================] - 71s 181ms/step - loss: 6.0411 - accuracy: 0.5766 - val_loss: 5.9794 - val_accuracy: 0.5913
# Epoch 34/100
# 395/395 [==============================] - 72s 182ms/step - loss: 5.9183 - accuracy: 0.5777 - val_loss: 5.9375 - val_accuracy: 0.5862
# Epoch 35/100
# 395/395 [==============================] - 72s 183ms/step - loss: 5.8065 - accuracy: 0.5906 - val_loss: 5.7532 - val_accuracy: 0.6442
# Epoch 36/100
# 395/395 [==============================] - 73s 184ms/step - loss: 5.6991 - accuracy: 0.6033 - val_loss: 5.6843 - val_accuracy: 0.6021
# Epoch 37/100
# 395/395 [==============================] - 73s 184ms/step - loss: 5.5873 - accuracy: 0.6109 - val_loss: 5.5548 - val_accuracy: 0.6202
# Epoch 38/100
# 395/395 [==============================] - 72s 183ms/step - loss: 5.5132 - accuracy: 0.5945 - val_loss: 5.4964 - val_accuracy: 0.6394
# Epoch 39/100
# 395/395 [==============================] - 72s 182ms/step - loss: 5.4103 - accuracy: 0.6036 - val_loss: 5.3990 - val_accuracy: 0.6649
# Epoch 40/100
# 395/395 [==============================] - 72s 183ms/step - loss: 5.3416 - accuracy: 0.6093 - val_loss: 5.2989 - val_accuracy: 0.6372
# Epoch 41/100
# 395/395 [==============================] - 73s 184ms/step - loss: 5.2377 - accuracy: 0.6112 - val_loss: 5.2756 - val_accuracy: 0.6790
# Epoch 42/100
# 395/395 [==============================] - 73s 185ms/step - loss: 5.1431 - accuracy: 0.6129 - val_loss: 5.1454 - val_accuracy: 0.6339
# Epoch 43/100
# 395/395 [==============================] - 73s 186ms/step - loss: 5.0442 - accuracy: 0.6267 - val_loss: 5.0744 - val_accuracy: 0.6679
# Epoch 44/100
# 395/395 [==============================] - 73s 185ms/step - loss: 4.9657 - accuracy: 0.6205 - val_loss: 4.9982 - val_accuracy: 0.6047
# Epoch 45/100
# 395/395 [==============================] - 72s 183ms/step - loss: 4.8775 - accuracy: 0.6228 - val_loss: 4.9056 - val_accuracy: 0.6091
# Epoch 46/100
# 395/395 [==============================] - 72s 183ms/step - loss: 4.8149 - accuracy: 0.6335 - val_loss: 4.8312 - val_accuracy: 0.6402
# Epoch 47/100
# 395/395 [==============================] - 72s 182ms/step - loss: 4.7225 - accuracy: 0.6348 - val_loss: 4.8256 - val_accuracy: 0.5673
# Epoch 48/100
# 395/395 [==============================] - 71s 181ms/step - loss: 4.6268 - accuracy: 0.6367 - val_loss: 4.7003 - val_accuracy: 0.6084
# Epoch 49/100
# 395/395 [==============================] - 71s 180ms/step - loss: 4.5637 - accuracy: 0.6353 - val_loss: 4.6159 - val_accuracy: 0.6609
# Epoch 50/100
# 395/395 [==============================] - 72s 181ms/step - loss: 4.5091 - accuracy: 0.6546 - val_loss: 4.5745 - val_accuracy: 0.6213
# Epoch 51/100
# 395/395 [==============================] - 73s 186ms/step - loss: 4.4229 - accuracy: 0.6453 - val_loss: 4.4771 - val_accuracy: 0.6694
# Epoch 52/100
# 395/395 [==============================] - 73s 186ms/step - loss: 4.3557 - accuracy: 0.6488 - val_loss: 4.4130 - val_accuracy: 0.6575
# Epoch 53/100
# 395/395 [==============================] - 73s 185ms/step - loss: 4.2849 - accuracy: 0.6573 - val_loss: 4.3484 - val_accuracy: 0.6860
# Epoch 54/100
# 395/395 [==============================] - 72s 183ms/step - loss: 4.2072 - accuracy: 0.6586 - val_loss: 4.2901 - val_accuracy: 0.6979
# Epoch 55/100
# 395/395 [==============================] - 72s 183ms/step - loss: 4.1601 - accuracy: 0.6560 - val_loss: 4.3119 - val_accuracy: 0.6139
# Epoch 56/100
# 395/395 [==============================] - 71s 180ms/step - loss: 4.0950 - accuracy: 0.6548 - val_loss: 4.1927 - val_accuracy: 0.6587
# Epoch 57/100
# 395/395 [==============================] - 71s 180ms/step - loss: 4.0263 - accuracy: 0.6692 - val_loss: 4.1190 - val_accuracy: 0.6731
# Epoch 58/100
# 395/395 [==============================] - 73s 184ms/step - loss: 3.9847 - accuracy: 0.6606 - val_loss: 4.0709 - val_accuracy: 0.6694
# Epoch 59/100
# 395/395 [==============================] - 73s 185ms/step - loss: 3.9075 - accuracy: 0.6657 - val_loss: 4.0242 - val_accuracy: 0.6964
# Epoch 60/100
# 395/395 [==============================] - 73s 185ms/step - loss: 3.8558 - accuracy: 0.6805 - val_loss: 4.0019 - val_accuracy: 0.6727
# Epoch 61/100
# 395/395 [==============================] - 72s 182ms/step - loss: 3.7678 - accuracy: 0.6865 - val_loss: 3.8954 - val_accuracy: 0.7119
# Epoch 62/100
# 395/395 [==============================] - 72s 183ms/step - loss: 3.7369 - accuracy: 0.6870 - val_loss: 3.8510 - val_accuracy: 0.6886
# Epoch 63/100
# 395/395 [==============================] - 73s 184ms/step - loss: 3.6912 - accuracy: 0.6863 - val_loss: 3.8025 - val_accuracy: 0.7034
# Epoch 64/100
# 395/395 [==============================] - 72s 182ms/step - loss: 3.6497 - accuracy: 0.6930 - val_loss: 3.7499 - val_accuracy: 0.6893
# Epoch 65/100
# 395/395 [==============================] - 72s 181ms/step - loss: 3.5736 - accuracy: 0.7015 - val_loss: 3.7399 - val_accuracy: 0.6794
# Epoch 66/100
# 395/395 [==============================] - 71s 181ms/step - loss: 3.5423 - accuracy: 0.7007 - val_loss: 3.6503 - val_accuracy: 0.6808
# Epoch 67/100
# 395/395 [==============================] - 71s 180ms/step - loss: 3.4731 - accuracy: 0.7034 - val_loss: 3.5960 - val_accuracy: 0.7112
# Epoch 68/100
# 395/395 [==============================] - 72s 181ms/step - loss: 3.4483 - accuracy: 0.7076 - val_loss: 3.5646 - val_accuracy: 0.6956
# Epoch 69/100
# 395/395 [==============================] - 72s 182ms/step - loss: 3.4106 - accuracy: 0.6898 - val_loss: 3.5157 - val_accuracy: 0.7252
# Epoch 70/100
# 395/395 [==============================] - 73s 186ms/step - loss: 3.3278 - accuracy: 0.7028 - val_loss: 3.4667 - val_accuracy: 0.7156
# Epoch 71/100
# 395/395 [==============================] - 72s 183ms/step - loss: 3.3183 - accuracy: 0.7069 - val_loss: 3.4305 - val_accuracy: 0.7404
# Epoch 72/100
# 395/395 [==============================] - 72s 183ms/step - loss: 3.2507 - accuracy: 0.6968 - val_loss: 3.3688 - val_accuracy: 0.6934
# Epoch 73/100
# 395/395 [==============================] - 72s 183ms/step - loss: 3.2104 - accuracy: 0.7123 - val_loss: 3.3484 - val_accuracy: 0.6890
# Epoch 74/100
# 395/395 [==============================] - 72s 183ms/step - loss: 3.1523 - accuracy: 0.7158 - val_loss: 3.2841 - val_accuracy: 0.7189
# Epoch 75/100
# 395/395 [==============================] - 73s 184ms/step - loss: 3.0911 - accuracy: 0.7171 - val_loss: 3.2952 - val_accuracy: 0.6871
# Epoch 76/100
# 395/395 [==============================] - 73s 185ms/step - loss: 3.0697 - accuracy: 0.7129 - val_loss: 3.2214 - val_accuracy: 0.7489
# Epoch 77/100
# 395/395 [==============================] - 73s 184ms/step - loss: 3.0308 - accuracy: 0.7164 - val_loss: 3.1705 - val_accuracy: 0.7445
# Epoch 78/100
# 395/395 [==============================] - 73s 184ms/step - loss: 3.0035 - accuracy: 0.7169 - val_loss: 3.1897 - val_accuracy: 0.7237
# Epoch 79/100
# 395/395 [==============================] - 72s 182ms/step - loss: 2.9521 - accuracy: 0.7320 - val_loss: 3.1485 - val_accuracy: 0.6868
# Epoch 80/100
# 395/395 [==============================] - 72s 182ms/step - loss: 2.9413 - accuracy: 0.7210 - val_loss: 3.0434 - val_accuracy: 0.7396
# Epoch 81/100
# 395/395 [==============================] - 71s 180ms/step - loss: 2.8914 - accuracy: 0.7358 - val_loss: 3.0305 - val_accuracy: 0.7178
# Epoch 82/100
# 395/395 [==============================] - 71s 179ms/step - loss: 2.8809 - accuracy: 0.7088 - val_loss: 2.9832 - val_accuracy: 0.6990
# Epoch 83/100
# 395/395 [==============================] - 71s 179ms/step - loss: 2.8283 - accuracy: 0.7217 - val_loss: 2.9254 - val_accuracy: 0.7589
# Epoch 84/100
# 395/395 [==============================] - 71s 180ms/step - loss: 2.7779 - accuracy: 0.7320 - val_loss: 2.9279 - val_accuracy: 0.7648
# Epoch 85/100
# 395/395 [==============================] - 71s 179ms/step - loss: 2.7277 - accuracy: 0.7375 - val_loss: 2.9436 - val_accuracy: 0.7319
# Epoch 86/100
# 395/395 [==============================] - 71s 179ms/step - loss: 2.6929 - accuracy: 0.7394 - val_loss: 2.8779 - val_accuracy: 0.7678
# Epoch 87/100
# 395/395 [==============================] - 70s 178ms/step - loss: 2.6566 - accuracy: 0.7459 - val_loss: 2.8132 - val_accuracy: 0.7219
# Epoch 88/100
# 395/395 [==============================] - 71s 179ms/step - loss: 2.6411 - accuracy: 0.7443 - val_loss: 2.8342 - val_accuracy: 0.7182
# Epoch 89/100
# 395/395 [==============================] - 77s 194ms/step - loss: 2.6213 - accuracy: 0.7250 - val_loss: 2.7583 - val_accuracy: 0.7286
# Epoch 90/100
# 395/395 [==============================] - 70s 177ms/step - loss: 2.5519 - accuracy: 0.7519 - val_loss: 2.7758 - val_accuracy: 0.7108
# Epoch 91/100
# 395/395 [==============================] - 70s 177ms/step - loss: 2.5548 - accuracy: 0.7456 - val_loss: 2.8145 - val_accuracy: 0.7359
# Epoch 92/100
# 395/395 [==============================] - 70s 177ms/step - loss: 2.5124 - accuracy: 0.7408 - val_loss: 2.6853 - val_accuracy: 0.7208
# Epoch 93/100
# 395/395 [==============================] - 71s 179ms/step - loss: 2.4780 - accuracy: 0.7523 - val_loss: 2.6437 - val_accuracy: 0.7175
# Epoch 94/100
# 395/395 [==============================] - 70s 178ms/step - loss: 2.4440 - accuracy: 0.7483 - val_loss: 2.6336 - val_accuracy: 0.7555
# Epoch 95/100
# 395/395 [==============================] - 70s 177ms/step - loss: 2.4173 - accuracy: 0.7565 - val_loss: 2.6510 - val_accuracy: 0.7456
# Epoch 96/100
# 395/395 [==============================] - 70s 178ms/step - loss: 2.3783 - accuracy: 0.7519 - val_loss: 2.5822 - val_accuracy: 0.7703
# Epoch 97/100
# 395/395 [==============================] - 71s 180ms/step - loss: 2.3733 - accuracy: 0.7531 - val_loss: 2.5833 - val_accuracy: 0.7426
# Epoch 98/100
# 395/395 [==============================] - 71s 179ms/step - loss: 2.3339 - accuracy: 0.7575 - val_loss: 2.5145 - val_accuracy: 0.7726
# Epoch 99/100
# 395/395 [==============================] - 73s 184ms/step - loss: 2.2936 - accuracy: 0.7637 - val_loss: 2.5118 - val_accuracy: 0.7482
# Epoch 100/100
# 395/395 [==============================] - 71s 179ms/step - loss: 2.2889 - accuracy: 0.7632 - val_loss: 2.5371 - val_accuracy: 0.7644

# %% [markdown]
# # Graph

# %% [markdown]
# ## Accuracy

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('accuracy')
plt.show()

# %% [markdown]
# ## Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('loss')
plt.show()

# %% [markdown]
# # Evaluate

# %%
test_model = load_model('/content/acc_densenet121_model.h5', compile=False)

# %%
y_pred = np.argmax(test_model.predict(x_test), axis=1)
print('balanced acc on test set:', balanced_accuracy_score(y_true=y_test, y_pred=y_pred))
# Out:
# balanced acc on test set: 0.7512828676921013

# %% [markdown]
# ## Classification Report

# %%
report = classification_report(y_true=y_test, y_pred=y_pred, target_names=label_names)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        akiec       0.53      0.58      0.55        33
#          bcc       0.64      0.78      0.70        41
#          bkl       0.60      0.65      0.62        99
#           df       0.41      0.85      0.55        13
#          mel       0.40      0.76      0.53       118
#           nv       0.97      0.77      0.85       681
#         vasc       0.75      0.88      0.81        17
#
#     accuracy                           0.75      1002
#    macro avg       0.61      0.75      0.66      1002
# weighted avg       0.83      0.75      0.77      1002

# %% [markdown]
# ## Confusion Matrix

# %%
cm = (confusion_matrix(y_true=y_test, y_pred=y_pred))

plot_confusion_matrix(cm, label_names)
# Out:
# Confusion matrix, without normalization
# [[ 19   3   5   1   4   1   0]
#  [  5  32   1   0   2   0   1]
#  [  2   3  64   2  22   6   0]
#  [  0   0   0  11   2   0   0]
#  [  6   2   8   1  90  11   0]
#  [  4  10  28  12 102 521   4]
#  [  0   0   1   0   1   0  15]]

# %% [markdown]
# ## Sensitivity & Specificity

# %%
total = sum(sum(cm))
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])

# %%
print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))
# Out:
# sensitivity: 0.8636
# specificity: 0.8649

# %% [markdown]
# # Grad-CAM

# %%
last_conv2d = 'conv5_block16_2_conv'

# %% [markdown]
# ## AKIEC

# %%
akiec_img = '/content/ham10000-with-one-image-folder/HAM1000_images/ISIC_0026492.jpg'

# %%
radcam, gb, guided_gradcam = compute_saliency(test_model, test_model, akiec_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.898
# 	nv             	(5)	with probability 0.054
# 	bkl            	(2)	with probability 0.015
# 	akiec          	(0)	with probability 0.010
# 	df             	(3)	with probability 0.009
# Explanation for 'mel'

# %% [markdown]
# ## BCC

# %%
bcc_img = '/content/ham10000-with-one-image-folder/HAM1000_images/ISIC_0024332.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(model, model, bcc_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	nv             	(5)	with probability 0.510
# 	bcc            	(1)	with probability 0.358
# 	vasc           	(6)	with probability 0.053
# 	bkl            	(2)	with probability 0.029
# 	mel            	(4)	with probability 0.018
# Explanation for 'nv'

# %%
bkl_img = '/content/ham10000-with-one-image-folder/HAM1000_images/ISIC_0025548.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(model, model, bkl_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.685
# 	bkl            	(2)	with probability 0.136
# 	nv             	(5)	with probability 0.111
# 	vasc           	(6)	with probability 0.025
# 	df             	(3)	with probability 0.024
# Explanation for 'mel'

# %% [markdown]
# ## DF

# %%
df_img = '/content/ham10000-with-one-image-folder/HAM1000_images/ISIC_0033626.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(model, model, df_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	nv             	(5)	with probability 0.625
# 	mel            	(4)	with probability 0.251
# 	df             	(3)	with probability 0.053
# 	bkl            	(2)	with probability 0.027
# 	vasc           	(6)	with probability 0.024
# Explanation for 'nv'

# %% [markdown]
# ## MEL

# %%
mel_img = '/content/ham10000-with-one-image-folder/HAM1000_images/ISIC_0024516.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(model, model, mel_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.624
# 	nv             	(5)	with probability 0.261
# 	bkl            	(2)	with probability 0.041
# 	vasc           	(6)	with probability 0.023
# 	akiec          	(0)	with probability 0.019
# Explanation for 'mel'

# %% [markdown]
# ## NV

# %%
nv_img = '/content/ham10000-with-one-image-folder/HAM1000_images/ISIC_0024349.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(model, model, nv_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	nv             	(5)	with probability 0.686
# 	vasc           	(6)	with probability 0.138
# 	mel            	(4)	with probability 0.101
# 	bkl            	(2)	with probability 0.034
# 	bcc            	(1)	with probability 0.016
# Explanation for 'nv'

# %% [markdown]
# ## VASC

# %%
vasc_img = '/content/ham10000-with-one-image-folder/HAM1000_images/ISIC_0025452.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(model, model, vasc_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	vasc           	(6)	with probability 1.000
# 	akiec          	(0)	with probability 0.000
# 	nv             	(5)	with probability 0.000
# 	bcc            	(1)	with probability 0.000
# 	df             	(3)	with probability 0.000
# Explanation for 'vasc'

# %% [markdown]
# # Download Model

# %%
from google.colab import files

# %%
files.download('/content/acc_densenet121_model.h5')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-50-0a6f2747a03c> in <module>()
# ----> 1 files.download('/content/acc_densenet121_model.h5')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: TypeError: Failed to fetch
