# %% [markdown]
# <a href="https://colab.research.google.com/github/fxlmer/JSTP22_Skin-Diseases-Classification-Using-Machine-Learning/blob/master/Ex1_HAM10000_VGG16_Ver2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Check GPU

# %%
# !nvidia-smi
# Out:
# Sat Feb 20 06:26:11 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import models
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Activation, Flatten, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
from tensorflow.keras.utils import Sequence
from imblearn.over_sampling import RandomOverSampler
from imblearn.keras import balanced_batch_generator

from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight, compute_sample_weight, compute_class_weight
from sklearn.metrics import balanced_accuracy_score, classification_report, confusion_matrix

import pandas as pd
import numpy as np
import os
import math
import itertools
from PIL import Image
from matplotlib import pyplot as plt

from ham10000_6classes_utils_functions_Ver2 import *
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# # Hyperparameters

# %%
IMG_WIDTH = 224
IMG_HEIGHT = 224
EPOCHS = 100
BATCH_SIZE = 32
NUM_CLASSES = 6

LR = 3e-5 # Learning rate

# %% [markdown]
# # Data Preparation

# %%
# !git clone https://github.com/EvilPickle-PCSHSPT/6_classes_HAM10000_split_Ver2
# Out:
# Cloning into '6_classes_HAM10000_split_Ver2'...
# remote: Enumerating objects: 1258, done.
# remote: Counting objects: 100% (1258/1258), done.
# remote: Compressing objects: 100% (1253/1253), done.
# remote: Total 5434 (delta 5), reused 1257 (delta 4), pack-reused 4176
# Receiving objects: 100% (5434/5434), 91.95 MiB | 42.05 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
train_path = '/content/6_classes_HAM10000_split_Ver2/images/pca-aug_train' 
val_path = '/content/6_classes_HAM10000_split_Ver2/images/cc_val'
test_path = '/content/6_classes_HAM10000_split_Ver2/images/cc_test'

# %% [markdown]
# # Data Augmentation

# %%
train_aug = ImageDataGenerator(rescale=1./255,
                               rotation_range=360,
                               zoom_range=0.1,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               horizontal_flip=True,
                               vertical_flip=True,
                               fill_mode='reflect')

val_aug = ImageDataGenerator(rescale=1./255)

test_aug = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_aug.flow_from_directory(train_path, 
                                                target_size=(IMG_WIDTH, IMG_HEIGHT), 
                                                batch_size=BATCH_SIZE, 
                                                shuffle=True,
                                                class_mode='categorical') 

val_generator = val_aug.flow_from_directory(val_path, 
                                              target_size=(IMG_WIDTH, IMG_HEIGHT), 
                                              batch_size=BATCH_SIZE, 
                                              shuffle=True,
                                              class_mode='categorical') 

test_generator = test_aug.flow_from_directory(test_path, 
                                               target_size=(IMG_WIDTH, IMG_HEIGHT), 
                                               batch_size=1, 
                                               shuffle=False,
                                               class_mode=None)
# Out:
# Found 4160 images belonging to 6 classes.
# Found 896 images belonging to 6 classes.
# Found 334 images belonging to 6 classes.

# %% [markdown]
# # Model

# %% [markdown]
# ## Build Model

# %%
def build_model_VGG16():
  base_model = tf.keras.applications.VGG16(include_top=False, input_shape=(IMG_WIDTH, IMG_HEIGHT, 3), weights='imagenet')
  average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
  prediction_layer = tf.keras.layers.Dense(units=NUM_CLASSES, activation='softmax', name='prediction')(average_pooling_layer)
  model = Model(inputs=base_model.input, outputs=prediction_layer)
  return model

# %%
model = build_model_VGG16()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# prediction (Dense)           (None, 6)                 3078
# =================================================================
# Total params: 14,717,766
# Trainable params: 14,717,766
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile

# %%
model.compile(optimizer=Adam(LR), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Callbacks

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')

model_checkpoint = ModelCheckpoint(filepath='HAM10000_VGG16_Ver2_model.h5', save_best_only=True, monitor='val_loss', mode='min')

reduce_lr_rate = ReduceLROnPlateau(monitor='val_loss', factor=0.3, min_lr=1e-7, patience=10, verbose=1, min_delta=1e-4, mode='min')

# %% [markdown]
# ## Training

# %%
history = model.fit(train_generator,
                    validation_data=val_generator,
                    epochs=EPOCHS,
                    callbacks=[early_stop, model_checkpoint, reduce_lr_rate],
                    verbose=1)
# Out:
# Epoch 1/100
# 130/130 [==============================] - ETA: 0s - batch: 64.5000 - size: 32.0000 - loss: 1.3463 - accuracy: 0.4570
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 130/130 [==============================] - 73s 481ms/step - batch: 64.5000 - size: 32.0000 - loss: 1.3463 - accuracy: 0.4570 - val_loss: 1.0907 - val_accuracy: 0.5558
# Epoch 2/100
# 130/130 [==============================] - 65s 501ms/step - batch: 64.5000 - size: 32.0000 - loss: 1.0277 - accuracy: 0.5916 - val_loss: 1.0276 - val_accuracy: 0.5804
# Epoch 3/100
# 130/130 [==============================] - 65s 499ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.9015 - accuracy: 0.6519 - val_loss: 1.0015 - val_accuracy: 0.6250
# Epoch 4/100
# 130/130 [==============================] - 65s 498ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.8215 - accuracy: 0.6815 - val_loss: 0.8363 - val_accuracy: 0.6629
# Epoch 5/100
# 130/130 [==============================] - 65s 499ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.7362 - accuracy: 0.7099 - val_loss: 0.7959 - val_accuracy: 0.6964
# Epoch 6/100
# 130/130 [==============================] - 65s 499ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.6820 - accuracy: 0.7380 - val_loss: 0.7356 - val_accuracy: 0.7188
# Epoch 7/100
# 130/130 [==============================] - 65s 497ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.6468 - accuracy: 0.7498 - val_loss: 0.7648 - val_accuracy: 0.7254
# Epoch 8/100
# 130/130 [==============================] - 64s 496ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.6013 - accuracy: 0.7712 - val_loss: 0.7717 - val_accuracy: 0.7098
# Epoch 9/100
# 130/130 [==============================] - 65s 497ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.5648 - accuracy: 0.7841 - val_loss: 0.7826 - val_accuracy: 0.7121
# Epoch 10/100
# 130/130 [==============================] - 64s 496ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.5208 - accuracy: 0.8084 - val_loss: 0.7457 - val_accuracy: 0.7422
# Epoch 11/100
# 130/130 [==============================] - 64s 496ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.4647 - accuracy: 0.8257 - val_loss: 0.8176 - val_accuracy: 0.7132
# Epoch 12/100
# 130/130 [==============================] - 65s 498ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.4701 - accuracy: 0.8269 - val_loss: 0.7095 - val_accuracy: 0.7455
# Epoch 13/100
# 130/130 [==============================] - 64s 494ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.4427 - accuracy: 0.8337 - val_loss: 0.7738 - val_accuracy: 0.7199
# Epoch 14/100
# 130/130 [==============================] - 64s 496ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.4003 - accuracy: 0.8548 - val_loss: 0.9065 - val_accuracy: 0.7065
# Epoch 15/100
# 130/130 [==============================] - 64s 496ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3842 - accuracy: 0.8560 - val_loss: 0.7976 - val_accuracy: 0.7455
# Epoch 16/100
# 130/130 [==============================] - 64s 496ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3274 - accuracy: 0.8740 - val_loss: 0.8757 - val_accuracy: 0.7087
# Epoch 17/100
# 130/130 [==============================] - 65s 497ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3176 - accuracy: 0.8764 - val_loss: 0.9224 - val_accuracy: 0.7444
# Epoch 18/100
# 130/130 [==============================] - 64s 496ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3521 - accuracy: 0.8704 - val_loss: 0.7876 - val_accuracy: 0.7600
# Epoch 19/100
# 130/130 [==============================] - 64s 497ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.2980 - accuracy: 0.8911 - val_loss: 1.0983 - val_accuracy: 0.7009
# Epoch 20/100
# 130/130 [==============================] - 64s 496ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.2647 - accuracy: 0.8962 - val_loss: 1.2674 - val_accuracy: 0.6886
# Epoch 21/100
# 130/130 [==============================] - 64s 495ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.2877 - accuracy: 0.8921 - val_loss: 0.8246 - val_accuracy: 0.7444
# Epoch 22/100
# 130/130 [==============================] - ETA: 0s - batch: 64.5000 - size: 32.0000 - loss: 0.2404 - accuracy: 0.9106
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 130/130 [==============================] - 65s 497ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.2404 - accuracy: 0.9106 - val_loss: 0.7614 - val_accuracy: 0.7768

# %% [markdown]
# # Training Graph

# %% [markdown]
# ## Accuracy

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('accuracy')
plt.show()

# %% [markdown]
# ## Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('loss')
plt.show()

# %% [markdown]
# # Evaluation

# %%
test_model = tf.keras.models.load_model('/content/HAM10000_VGG16_Ver2_model.h5')

# %%
num_test_files = len(test_generator.filenames)

# %%
test_generator.reset()

# %%
test_labels = test_generator.classes
predictions = test_model.predict(test_generator, steps=num_test_files//test_generator.batch_size)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '

# %% [markdown]
# ## Confusion Matrix

# %% [markdown]
# ### Without Normalize

# %%
cm = confusion_matrix(test_labels, predictions.argmax(axis=1))

classes_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'vasc']

plot_confusion_matrix(cm, classes_names, False)
# Out:
# Confusion matrix, without normalization
# [[19  4  6  0  4  0]
#  [ 1 41  4  0  6  0]
#  [ 2  4 86  1 17  0]
#  [ 2  1  1  7  1  0]
#  [ 4  3 20  0 85  0]
#  [ 0  0  0  0  1 14]]

# %% [markdown]
# ### With Normalize

# %%
plot_confusion_matrix(cm, classes_names, True)
# Out:
# Normalized confusion matrix
# [[0.57575758 0.12121212 0.18181818 0.         0.12121212 0.        ]
#  [0.01923077 0.78846154 0.07692308 0.         0.11538462 0.        ]
#  [0.01818182 0.03636364 0.78181818 0.00909091 0.15454545 0.        ]
#  [0.16666667 0.08333333 0.08333333 0.58333333 0.08333333 0.        ]
#  [0.03571429 0.02678571 0.17857143 0.         0.75892857 0.        ]
#  [0.         0.         0.         0.         0.06666667 0.93333333]]

# %% [markdown]
# ## Classification Report

# %%
y_pred = np.argmax(predictions, axis=1)
print('Confusion Matrix')
print(confusion_matrix(test_labels, y_pred))
print('Classification Report')
print(classification_report(test_labels, y_pred, target_names=classes_names))
# Out:
# Confusion Matrix
# [[19  4  6  0  4  0]
#  [ 1 41  4  0  6  0]
#  [ 2  4 86  1 17  0]
#  [ 2  1  1  7  1  0]
#  [ 4  3 20  0 85  0]
#  [ 0  0  0  0  1 14]]
# Classification Report
#               precision    recall  f1-score   support
#
#        akiec       0.68      0.58      0.62        33
#          bcc       0.77      0.79      0.78        52
#          bkl       0.74      0.78      0.76       110
#           df       0.88      0.58      0.70        12
#          mel       0.75      0.76      0.75       112
#         vasc       1.00      0.93      0.97        15
#
#     accuracy                           0.75       334
#    macro avg       0.80      0.74      0.76       334
# weighted avg       0.76      0.75      0.75       334

# %% [markdown]
# ## TP FP FN TN

# %%
cm_2 = confusion_matrix(test_labels, y_pred)

# %% [markdown]
# ### TP

# %%
TruePositive= np.diag(cm_2)

# %%
print(TruePositive)
sumTruePositive = sum(TruePositive)
print('Sum of True Positive: ', sumTruePositive)
# Out:
# [19 41 86  7 85 14]
# Sum of True Positive:  252

# %% [markdown]
# ### FP

# %%
FalsePositive = []
for i in range(NUM_CLASSES):
    FalsePositive.append(sum(cm_2[:,i]) - cm_2[i,i])

# %%
print(FalsePositive)
sumFalsePositive = sum(FalsePositive)
print('Sum of False Positive: ', sumFalsePositive)
# Out:
# [9, 12, 31, 1, 29, 0]
# Sum of False Positive:  82

# %% [markdown]
# ### FN

# %%
FalseNegative = []
for i in range(NUM_CLASSES):
    FalseNegative.append(sum(cm_2[i,:]) - cm_2[i,i])

# %%
print(FalseNegative)
sumFalseNegative = sum(FalseNegative)
print('Sum of False Negative: ', sumFalseNegative)
# Out:
# [14, 11, 24, 5, 27, 1]
# Sum of False Negative:  82

# %% [markdown]
# ### TN

# %%
TrueNegative = []
for i in range(NUM_CLASSES):
    temp = np.delete(cm_2, i, 0)   # delete ith row
    temp = np.delete(temp, i, 1)  # delete ith column
    TrueNegative.append(sum(sum(temp)))

# %%
print(TrueNegative)
sumTrueNegative = sum(TrueNegative)
print('Sum of True Negative: ', sumTrueNegative)
# Out:
# [292, 270, 193, 321, 193, 319]
# Sum of True Negative:  1588

# %% [markdown]
# ## Check TP + FP + FN + TN = Test set

# %%
l = len(test_labels)
for i in range(NUM_CLASSES):
    print(TruePositive[i] + FalsePositive[i] + FalseNegative[i] + TrueNegative[i] == l)
# Out:
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ## PYCM

# %%
# !pip3 install pycm==3.0
# Out:
# Collecting pycm==3.0
#   Downloading https://files.pythonhosted.org/packages/07/e0/de92301a06bf5e2d24e04edc178ee457b49dbad2606c3252949222110f4d/pycm-3.0-py2.py3-none-any.whl (61kB)
#      |████████████████████████████████| 71kB 9.4MB/s
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pycm==3.0) (1.19.5)
# Collecting art>=1.8
#   Downloading https://files.pythonhosted.org/packages/83/37/c28d69ba1005889e8ff9633b8e7eccaaddc03549058a51ef5f51853cf183/art-5.1-py2.py3-none-any.whl (567kB)
#      |████████████████████████████████| 573kB 24.4MB/s
# Installing collected packages: art, pycm
# Successfully installed art-5.1 pycm-3.0

# %%
from pycm import *

# %%
py_cm = ConfusionMatrix(actual_vector=test_labels, predict_vector=y_pred)

# %%
py_cm.classes
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
py_cm.table
# Out:
# {0: {0: 19, 1: 4, 2: 6, 3: 0, 4: 4, 5: 0},
#  1: {0: 1, 1: 41, 2: 4, 3: 0, 4: 6, 5: 0},
#  2: {0: 2, 1: 4, 2: 86, 3: 1, 4: 17, 5: 0},
#  3: {0: 2, 1: 1, 2: 1, 3: 7, 4: 1, 5: 0},
#  4: {0: 4, 1: 3, 2: 20, 3: 0, 4: 85, 5: 0},
#  5: {0: 0, 1: 0, 2: 0, 3: 0, 4: 1, 5: 14}}

# %%
print(py_cm)
# Out:
# Predict  0        1        2        3        4        5
# Actual
# 0        19       4        6        0        4        0
#
# 1        1        41       4        0        6        0
#
# 2        2        4        86       1        17       0
#
# 3        2        1        1        7        1        0
#
# 4        4        3        20       0        85       0
#
# 5        0        0        0        0        1        14
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (0.70833,0.80065)
# ACC Macro                                                         0.91816
# ARI                                                               0.44923
# AUNP                                                              0.82771
# AUNU                                                              0.83975
# Bangdiwala B                                                      0.57075
# Bennett S                                                         0.70539
# CBA                                                               0.72444
# CSI                                                               0.53824
# Chi-Squared                                                       901.10226
# Chi-Squared DF                                                    25
# Conditional Entropy                                               1.09701
# Cramer V                                                          0.73456
# Cross Entropy                                                     2.18422
# F1 Macro                                                          0.76322
# F1 Micro                                                          0.75449
# FNR Macro                                                         0.26306
# FNR Micro                                                         0.24551
# FPR Macro                                                         0.05743
# FPR Micro                                                         0.0491
# Gwet AC1                                                          0.71223
# Hamming Loss                                                      0.24551
# Joint Entropy                                                     3.27448
# KL Divergence                                                     0.00675
# Kappa                                                             0.66572
# Kappa 95% CI                                                      (0.60288,0.72857)
# Kappa No Prevalence                                               0.50898
# Kappa Standard Error                                              0.03206
# Kappa Unbiased                                                    0.66562
# Krippendorff Alpha                                                0.66613
# Lambda A                                                          0.63063
# Lambda B                                                          0.62212
# Mutual Information                                                1.00444
# NIR                                                               0.33533
# Overall ACC                                                       0.75449
# Overall CEN                                                       0.32384
# Overall J                                                         (3.77757,0.62959)
# Overall MCC                                                       0.66615
# Overall MCEN                                                      0.44085
# Overall RACC                                                      0.26555
# Overall RACCU                                                     0.26577
# P-Value                                                           0.0
# PPV Macro                                                         0.8013
# PPV Micro                                                         0.75449
# Pearson C                                                         0.85415
# Phi-Squared                                                       2.69791
# RCI                                                               0.46129
# RR                                                                55.66667
# Reference Entropy                                                 2.17746
# Response Entropy                                                  2.10146
# SOA1(Landis & Koch)                                               Substantial
# SOA2(Fleiss)                                                      Intermediate to Good
# SOA3(Altman)                                                      Good
# SOA4(Cicchetti)                                                   Good
# SOA5(Cramer)                                                      Strong
# SOA6(Matthews)                                                    Moderate
# Scott PI                                                          0.66562
# Standard Error                                                    0.02355
# TNR Macro                                                         0.94257
# TNR Micro                                                         0.9509
# TPR Macro                                                         0.73694
# TPR Micro                                                         0.75449
# Zero-one Loss                                                     82
#
# Class Statistics :
#
# Classes                                                           0             1             2             3             4             5
# ACC(Accuracy)                                                     0.93114       0.93114       0.83533       0.98204       0.83234       0.99701
# AGF(Adjusted F-score)                                             0.75395       0.86842       0.82596       0.78545       0.81377       0.97138
# AGM(Adjusted geometric mean)                                      0.85294       0.90941       0.83715       0.87759       0.83507       0.98266
# AM(Difference between automatic and manual classification)        -5            1             7             -4            2             -1
# AUC(Area under the ROC curve)                                     0.77293       0.87295       0.82171       0.79011       0.81415       0.96667
# AUCI(AUC value interpretation)                                    Good          Very Good     Very Good     Good          Very Good     Excellent
# AUPR(Area under the PR curve)                                     0.62716       0.78102       0.75843       0.72917       0.75227       0.96667
# BCD(Bray-Curtis dissimilarity)                                    0.00749       0.0015        0.01048       0.00599       0.00299       0.0015
# BM(Informedness or bookmaker informedness)                        0.54586       0.74591       0.64343       0.58023       0.6283        0.93333
# CEN(Confusion entropy)                                            0.45844       0.31583       0.31963       0.36021       0.32732       0.05043
# DOR(Diagnostic odds ratio)                                        44.03175      83.86364      22.30914      449.4         20.95147      None
# DP(Discriminant power)                                            0.90626       1.06052       0.74346       1.46247       0.72842       None
# DPI(Discriminant power interpretation)                            Poor          Limited       Poor          Limited       Poor          None
# ERR(Error rate)                                                   0.06886       0.06886       0.16467       0.01796       0.16766       0.00299
# F0.5(F0.5 score)                                                  0.65517       0.77652       0.74394       0.79545       0.74824       0.98592
# F1(F1 score - harmonic mean of precision and sensitivity)         0.62295       0.78095       0.75771       0.7           0.75221       0.96552
# F2(F2 score)                                                      0.59375       0.78544       0.77199       0.625         0.75623       0.94595
# FDR(False discovery rate)                                         0.32143       0.22642       0.26496       0.125         0.25439       0.0
# FN(False negative/miss/type 2 error)                              14            11            24            5             27            1
# FNR(Miss rate or false negative rate)                             0.42424       0.21154       0.21818       0.41667       0.24107       0.06667
# FOR(False omission rate)                                          0.04575       0.03915       0.1106        0.01534       0.12273       0.00313
# FP(False positive/type 1 error/false alarm)                       9             12            31            1             29            0
# FPR(Fall-out or false positive rate)                              0.0299        0.04255       0.13839       0.00311       0.13063       0.0
# G(G-measure geometric mean of precision and sensitivity)          0.62505       0.78099       0.75807       0.71443       0.75224       0.96609
# GI(Gini index)                                                    0.54586       0.74591       0.64343       0.58023       0.6283        0.93333
# GM(G-mean geometric mean of specificity and sensitivity)          0.74736       0.86886       0.82074       0.76258       0.81227       0.96609
# IBA(Index of balanced accuracy)                                   0.33829       0.62734       0.61987       0.34103       0.58692       0.87111
# ICSI(Individual classification success index)                     0.25433       0.56205       0.51686       0.45833       0.50454       0.93333
# IS(Information score)                                             2.77988       2.3129        1.15824       4.6061        1.15285       4.47681
# J(Jaccard index)                                                  0.45238       0.64062       0.60993       0.53846       0.60284       0.93333
# LS(Lift score)                                                    6.86797       4.9688        2.23186       24.35417      2.22353       22.26667
# MCC(Matthews correlation coefficient)                             0.58773       0.74015       0.63386       0.70626       0.62559       0.96458
# MCCI(Matthews correlation coefficient interpretation)             Moderate      Strong        Moderate      Strong        Moderate      Very Strong
# MCEN(Modified confusion entropy)                                  0.57707       0.44089       0.43391       0.46782       0.44327       0.07841
# MK(Markedness)                                                    0.63282       0.73444       0.62444       0.85966       0.62289       0.99688
# N(Condition negative)                                             301           282           224           322           222           319
# NLR(Negative likelihood ratio)                                    0.43732       0.22094       0.25323       0.41796       0.27729       0.06667
# NLRI(Negative likelihood ratio interpretation)                    Poor          Poor          Poor          Poor          Poor          Good
# NPV(Negative predictive value)                                    0.95425       0.96085       0.8894        0.98466       0.87727       0.99688
# OC(Overlap coefficient)                                           0.67857       0.78846       0.78182       0.875         0.75893       1.0
# OOC(Otsuka-Ochiai coefficient)                                    0.62505       0.78099       0.75807       0.71443       0.75224       0.96609
# OP(Optimized precision)                                           0.67604       0.83435       0.78678       0.72033       0.76451       0.96252
# P(Condition positive or support)                                  33            52            110           12            112           15
# PLR(Positive likelihood ratio)                                    19.25589      18.52885      5.64927       187.83333     5.80973       None
# PLRI(Positive likelihood ratio interpretation)                    Good          Good          Fair          Good          Fair          None
# POP(Population)                                                   334           334           334           334           334           334
# PPV(Precision or positive predictive value)                       0.67857       0.77358       0.73504       0.875         0.74561       1.0
# PRE(Prevalence)                                                   0.0988        0.15569       0.32934       0.03593       0.33533       0.04491
# Q(Yule Q - coefficient of colligation)                            0.95559       0.97643       0.9142        0.99556       0.90889       None
# QI(Yule Q interpretation)                                         Strong        Strong        Strong        Strong        Strong        None
# RACC(Random accuracy)                                             0.00828       0.02471       0.11537       0.00086       0.11445       0.00188
# RACCU(Random accuracy unbiased)                                   0.00834       0.02471       0.11548       0.0009        0.11446       0.00188
# TN(True negative/correct rejection)                               292           270           193           321           193           319
# TNR(Specificity or true negative rate)                            0.9701        0.95745       0.86161       0.99689       0.86937       1.0
# TON(Test outcome negative)                                        306           281           217           326           220           320
# TOP(Test outcome positive)                                        28            53            117           8             114           14
# TP(True positive/hit)                                             19            41            86            7             85            14
# TPR(Sensitivity, recall, hit rate, or true positive rate)         0.57576       0.78846       0.78182       0.58333       0.75893       0.93333
# Y(Youden index)                                                   0.54586       0.74591       0.64343       0.58023       0.6283        0.93333
# dInd(Distance index)                                              0.42529       0.21578       0.25837       0.41668       0.27419       0.06667
# sInd(Similarity index)                                            0.69927       0.84742       0.8173        0.70536       0.80612       0.95286

# %% [markdown]
# ### Average AUC

# %%
AV_AUC = (py_cm.AUC[0] + py_cm.AUC[1] + py_cm.AUC[2] + py_cm.AUC[3] + py_cm.AUC[4] + py_cm.AUC[5])/len(py_cm.AUC)

# %%
print('Average AUC: ', AV_AUC)
# Out:
# Average AUC:  0.8397541610484717

# %% [markdown]
# ### Average Sensitivity

# %%
AV_Sens = (py_cm.TPR[0] + py_cm.TPR[1] + py_cm.TPR[2] + py_cm.TPR[3] + py_cm.TPR[4] + py_cm.TPR[5])/len(py_cm.TPR)

# %%
print('Average Sensitivity: ', AV_Sens)
# Out:
# Average Sensitivity:  0.7369387556887558

# %% [markdown]
# ### Average Specificity

# %%
AV_Spec = (py_cm.TNR[0] + py_cm.TNR[1] + py_cm.TNR[2] + py_cm.TNR[3] + py_cm.TNR[4] + py_cm.TNR[5])/len(py_cm.TNR)

# %%
print('Average Specificity: ', AV_Spec)
# Out:
# Average Specificity:  0.9425695664081876

# %% [markdown]
# ## Grad-CAM

# %%
last_conv2d = 'block5_conv3'

# %% [markdown]
# ### AKIEC

# %%
akiec_img = '/content/6_classes_HAM10000_split_Ver2/images/pca-aug_train/akiec/ISIC_0026492.jpg'

# %%
 gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, akiec_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.993
# 	bkl            	(2)	with probability 0.006
# 	akiec          	(0)	with probability 0.001
# 	df             	(3)	with probability 0.000
# 	bcc            	(1)	with probability 0.000
# Explanation for 'mel'

# %% [markdown]
# ### BCC

# %%
bcc_img = '/content/6_classes_HAM10000_split_Ver2/images/pca-aug_train/bcc/ISIC_0024332.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, bcc_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.757
# 	bcc            	(1)	with probability 0.225
# 	akiec          	(0)	with probability 0.014
# 	bkl            	(2)	with probability 0.003
# 	df             	(3)	with probability 0.001
# Explanation for 'mel'

# %% [markdown]
# ### BKL

# %%
bkl_img = '/content/6_classes_HAM10000_split_Ver2/images/pca-aug_train/bkl/ISIC_0025548.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, bkl_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.793
# 	bkl            	(2)	with probability 0.205
# 	akiec          	(0)	with probability 0.001
# 	bcc            	(1)	with probability 0.000
# 	df             	(3)	with probability 0.000
# Explanation for 'mel'

# %% [markdown]
# ### DF

# %%
df_img = '/content/6_classes_HAM10000_split_Ver2/images/cc_val/df/ISIC_0033626.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, df_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.891
# 	df             	(3)	with probability 0.069
# 	akiec          	(0)	with probability 0.029
# 	bkl            	(2)	with probability 0.011
# 	bcc            	(1)	with probability 0.000
# Explanation for 'mel'

# %% [markdown]
# ### MEL

# %%
mel_img = '/content/6_classes_HAM10000_split_Ver2/images/pca-aug_train/mel/ISIC_0024516.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, mel_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.996
# 	bkl            	(2)	with probability 0.004
# 	akiec          	(0)	with probability 0.000
# 	df             	(3)	with probability 0.000
# 	bcc            	(1)	with probability 0.000
# Explanation for 'mel'

# %% [markdown]
# ### VASC

# %%
vasc_img = '/content/6_classes_HAM10000_split_Ver2/images/cc_test/vasc/ISIC_0025452.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, vasc_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	vasc           	(5)	with probability 1.000
# 	mel            	(4)	with probability 0.000
# 	bcc            	(1)	with probability 0.000
# 	akiec          	(0)	with probability 0.000
# 	df             	(3)	with probability 0.000
# Explanation for 'vasc'

# %% [markdown]
# # Download Model

# %%
from google.colab import files

# %%
files.download('/content/HAM10000_VGG16_Ver2_model.h5')
