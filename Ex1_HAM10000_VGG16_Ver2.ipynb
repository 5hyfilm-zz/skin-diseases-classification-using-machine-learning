# %% [markdown]
# <a href="https://colab.research.google.com/github/fxlmer/JSTP22_Skin-Diseases-Classification-Using-Machine-Learning/blob/master/Ex1_HAM10000_VGG16_Ver2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Check GPU

# %%
# !nvidia-smi
# Out:
# Thu Feb 18 13:07:24 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8    32W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import models
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Activation, Flatten, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
from tensorflow.keras.utils import Sequence
from imblearn.over_sampling import RandomOverSampler
from imblearn.keras import balanced_batch_generator

from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight, compute_sample_weight, compute_class_weight
from sklearn.metrics import balanced_accuracy_score, classification_report, confusion_matrix

import pandas as pd
import numpy as np
import os
import math
import itertools
from PIL import Image
from matplotlib import pyplot as plt

from ham10000_6classes_utils_functions_Ver2 import *
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# # Hyperparameters

# %%
IMG_WIDTH = 224
IMG_HEIGHT = 224
EPOCHS = 100
BATCH_SIZE = 32
NUM_CLASSES = 6

LR = 3e-5 # Learning rate

# %% [markdown]
# # Data Preparation

# %%
# !git clone https://github.com/EvilPickle-PCSHSPT/6_classes_HAM10000_split_Ver2
# Out:
# Cloning into '6_classes_HAM10000_split_Ver2'...
# remote: Enumerating objects: 1258, done.
# remote: Counting objects: 100% (1258/1258), done.
# remote: Compressing objects: 100% (1253/1253), done.
# remote: Total 5434 (delta 5), reused 1257 (delta 4), pack-reused 4176
# Receiving objects: 100% (5434/5434), 91.95 MiB | 21.54 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
train_path = '/content/6_classes_HAM10000_split_Ver2/images/pca-aug_train' 
val_path = '/content/6_classes_HAM10000_split_Ver2/images/cc_val'
test_path = '/content/6_classes_HAM10000_split_Ver2/images/cc_test'

# %% [markdown]
# # Data Augmentation

# %%
train_aug = ImageDataGenerator(rescale=1./255,
                               rotation_range=360,
                               zoom_range=0.1,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               horizontal_flip=True,
                               vertical_flip=True,
                               fill_mode='reflect')

val_aug = ImageDataGenerator(rescale=1./255)

test_aug = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_aug.flow_from_directory(train_path, 
                                                target_size=(IMG_WIDTH, IMG_HEIGHT), 
                                                batch_size=BATCH_SIZE, 
                                                shuffle=True,
                                                class_mode='categorical') 

val_generator = train_aug.flow_from_directory(val_path, 
                                              target_size=(IMG_WIDTH, IMG_HEIGHT), 
                                              batch_size=BATCH_SIZE, 
                                              shuffle=True,
                                              class_mode='categorical') 

test_generator = train_aug.flow_from_directory(test_path, 
                                               target_size=(IMG_WIDTH, IMG_HEIGHT), 
                                               batch_size=1, 
                                               shuffle=False,
                                               class_mode=None)
# Out:
# Found 4160 images belonging to 6 classes.
# Found 896 images belonging to 6 classes.
# Found 334 images belonging to 6 classes.

# %% [markdown]
# # Model

# %% [markdown]
# ## Build Model

# %%
def build_model_VGG16():
  base_model = tf.keras.applications.VGG16(include_top=False, input_shape=(IMG_WIDTH, IMG_HEIGHT, 3), weights='imagenet')
  average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
  prediction_layer = tf.keras.layers.Dense(units=NUM_CLASSES, activation='softmax', name='prediction')(average_pooling_layer)
  model = Model(inputs=base_model.input, outputs=prediction_layer)
  return model

# %%
model = build_model_VGG16()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# prediction (Dense)           (None, 6)                 3078
# =================================================================
# Total params: 14,717,766
# Trainable params: 14,717,766
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile

# %%
model.compile(optimizer=Adam(LR), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Callbacks

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')

model_checkpoint = ModelCheckpoint(filepath='HAM10000_VGG16_Ver2_model.h5', save_best_only=True, monitor='val_loss', mode='min')

reduce_lr_rate = ReduceLROnPlateau(monitor='val_loss', factor=0.3, min_lr=1e-7, patience=10, verbose=1, min_delta=1e-4, mode='min')

# %% [markdown]
# ## Training

# %%
history = model.fit(train_generator,
                    validation_data=val_generator,
                    epochs=EPOCHS,
                    callbacks=[early_stop, model_checkpoint, reduce_lr_rate],
                    verbose=1)
# Out:
# Epoch 1/100
# 130/130 [==============================] - ETA: 0s - batch: 64.5000 - size: 32.0000 - loss: 1.3810 - accuracy: 0.4373
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 130/130 [==============================] - 137s 935ms/step - batch: 64.5000 - size: 32.0000 - loss: 1.3810 - accuracy: 0.4373 - val_loss: 1.2089 - val_accuracy: 0.5357
# Epoch 2/100
# 130/130 [==============================] - 122s 939ms/step - batch: 64.5000 - size: 32.0000 - loss: 1.0902 - accuracy: 0.5683 - val_loss: 1.0216 - val_accuracy: 0.5971
# Epoch 3/100
# 130/130 [==============================] - 122s 938ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.9487 - accuracy: 0.6248 - val_loss: 0.9064 - val_accuracy: 0.6496
# Epoch 4/100
# 130/130 [==============================] - 122s 939ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.8325 - accuracy: 0.6767 - val_loss: 0.8902 - val_accuracy: 0.6540
# Epoch 5/100
# 130/130 [==============================] - 122s 939ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.7777 - accuracy: 0.6990 - val_loss: 0.8713 - val_accuracy: 0.6451
# Epoch 6/100
# 130/130 [==============================] - 122s 939ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.6912 - accuracy: 0.7423 - val_loss: 0.8251 - val_accuracy: 0.6864
# Epoch 7/100
# 130/130 [==============================] - 122s 941ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.6620 - accuracy: 0.7435 - val_loss: 0.7653 - val_accuracy: 0.6998
# Epoch 8/100
# 130/130 [==============================] - 122s 936ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.6031 - accuracy: 0.7678 - val_loss: 0.8142 - val_accuracy: 0.6942
# Epoch 9/100
# 130/130 [==============================] - 122s 937ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.5505 - accuracy: 0.7885 - val_loss: 0.8653 - val_accuracy: 0.6975
# Epoch 10/100
# 130/130 [==============================] - 122s 940ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.5559 - accuracy: 0.7897 - val_loss: 0.7456 - val_accuracy: 0.7277
# Epoch 11/100
# 130/130 [==============================] - 122s 938ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.4999 - accuracy: 0.8077 - val_loss: 0.8336 - val_accuracy: 0.6975
# Epoch 12/100
# 130/130 [==============================] - 122s 937ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.4560 - accuracy: 0.8274 - val_loss: 0.7540 - val_accuracy: 0.7355
# Epoch 13/100
# 130/130 [==============================] - 122s 940ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.4461 - accuracy: 0.8308 - val_loss: 0.7234 - val_accuracy: 0.7355
# Epoch 14/100
# 130/130 [==============================] - 122s 938ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3997 - accuracy: 0.8486 - val_loss: 0.7451 - val_accuracy: 0.7478
# Epoch 15/100
# 130/130 [==============================] - 122s 937ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3868 - accuracy: 0.8514 - val_loss: 0.8570 - val_accuracy: 0.7199
# Epoch 16/100
# 130/130 [==============================] - 122s 940ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3702 - accuracy: 0.8577 - val_loss: 0.9031 - val_accuracy: 0.6875
# Epoch 17/100
# 130/130 [==============================] - 122s 937ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3367 - accuracy: 0.8724 - val_loss: 0.7889 - val_accuracy: 0.7444
# Epoch 18/100
# 130/130 [==============================] - 122s 938ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3012 - accuracy: 0.8865 - val_loss: 0.8602 - val_accuracy: 0.7310
# Epoch 19/100
# 130/130 [==============================] - 122s 937ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3091 - accuracy: 0.8805 - val_loss: 0.9321 - val_accuracy: 0.7321
# Epoch 20/100
# 130/130 [==============================] - 122s 938ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.2975 - accuracy: 0.8863 - val_loss: 0.7647 - val_accuracy: 0.7712
# Epoch 21/100
# 130/130 [==============================] - 122s 936ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.2742 - accuracy: 0.8998 - val_loss: 0.7533 - val_accuracy: 0.7723
# Epoch 22/100
# 130/130 [==============================] - 122s 938ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.2518 - accuracy: 0.9067 - val_loss: 0.8446 - val_accuracy: 0.7467
# Epoch 23/100
# 130/130 [==============================] - ETA: 0s - batch: 64.5000 - size: 32.0000 - loss: 0.2432 - accuracy: 0.9115
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 130/130 [==============================] - 122s 937ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.2432 - accuracy: 0.9115 - val_loss: 0.8209 - val_accuracy: 0.7634

# %% [markdown]
# # Training Graph

# %% [markdown]
# ## Accuracy

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('accuracy')
plt.show()

# %% [markdown]
# ## Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('loss')
plt.show()

# %% [markdown]
# # Evaluation

# %%
test_model = tf.keras.models.load_model('/content/HAM10000_VGG16_Ver2_model.h5')

# %%
num_test_files = len(test_generator.filenames)

# %%
test_generator.reset()

# %%
test_labels = test_generator.classes
predictions = test_model.predict(test_generator, steps=num_test_files//test_generator.batch_size)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '

# %% [markdown]
# ## Confusion Matrix

# %% [markdown]
# ### Without Normalize

# %%
cm = confusion_matrix(test_labels, predictions.argmax(axis=1))

classes_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'vasc']

plot_confusion_matrix(cm, classes_names, False)
# Out:
# Confusion matrix, without normalization
# [[17  5  7  1  3  0]
#  [ 2 41  5  0  4  0]
#  [ 3  5 86  1 15  0]
#  [ 1  0  1 10  0  0]
#  [ 4  2 17  2 87  0]
#  [ 0  0  1  1  0 13]]

# %% [markdown]
# ### With Normalize

# %%
plot_confusion_matrix(cm, classes_names, True)
# Out:
# Normalized confusion matrix
# [[0.51515152 0.15151515 0.21212121 0.03030303 0.09090909 0.        ]
#  [0.03846154 0.78846154 0.09615385 0.         0.07692308 0.        ]
#  [0.02727273 0.04545455 0.78181818 0.00909091 0.13636364 0.        ]
#  [0.08333333 0.         0.08333333 0.83333333 0.         0.        ]
#  [0.03571429 0.01785714 0.15178571 0.01785714 0.77678571 0.        ]
#  [0.         0.         0.06666667 0.06666667 0.         0.86666667]]

# %% [markdown]
# ## Classification Report

# %%
y_pred = np.argmax(predictions, axis=1)
print('Confusion Matrix')
print(confusion_matrix(test_labels, y_pred))
print('Classification Report')
print(classification_report(test_labels, y_pred, target_names=classes_names))
# Out:
# Confusion Matrix
# [[17  5  7  1  3  0]
#  [ 2 41  5  0  4  0]
#  [ 3  5 86  1 15  0]
#  [ 1  0  1 10  0  0]
#  [ 4  2 17  2 87  0]
#  [ 0  0  1  1  0 13]]
# Classification Report
#               precision    recall  f1-score   support
#
#        akiec       0.63      0.52      0.57        33
#          bcc       0.77      0.79      0.78        52
#          bkl       0.74      0.78      0.76       110
#           df       0.67      0.83      0.74        12
#          mel       0.80      0.78      0.79       112
#         vasc       1.00      0.87      0.93        15
#
#     accuracy                           0.76       334
#    macro avg       0.77      0.76      0.76       334
# weighted avg       0.76      0.76      0.76       334

# %% [markdown]
# ## TP FP FN TN

# %%
cm_2 = confusion_matrix(test_labels, y_pred)

# %% [markdown]
# ### TP

# %%
TruePositive= np.diag(cm_2)

# %%
print(TruePositive)
sumTruePositive = sum(TruePositive)
print('Sum of True Positive: ', sumTruePositive)
# Out:
# [17 41 86 10 87 13]
# Sum of True Positive:  254

# %% [markdown]
# ### FP

# %%
FalsePositive = []
for i in range(NUM_CLASSES):
    FalsePositive.append(sum(cm_2[:,i]) - cm_2[i,i])

# %%
print(FalsePositive)
sumFalsePositive = sum(FalsePositive)
print('Sum of False Positive: ', sumFalsePositive)
# Out:
# [10, 12, 31, 5, 22, 0]
# Sum of False Positive:  80

# %% [markdown]
# ### FN

# %%
FalseNegative = []
for i in range(NUM_CLASSES):
    FalseNegative.append(sum(cm_2[i,:]) - cm_2[i,i])

# %%
print(FalseNegative)
sumFalseNegative = sum(FalseNegative)
print('Sum of False Negative: ', sumFalseNegative)
# Out:
# [16, 11, 24, 2, 25, 2]
# Sum of False Negative:  80

# %% [markdown]
# ### TN

# %%
TrueNegative = []
for i in range(NUM_CLASSES):
    temp = np.delete(cm_2, i, 0)   # delete ith row
    temp = np.delete(temp, i, 1)  # delete ith column
    TrueNegative.append(sum(sum(temp)))

# %%
print(TrueNegative)
sumTrueNegative = sum(TrueNegative)
print('Sum of True Negative: ', sumTrueNegative)
# Out:
# [291, 270, 193, 317, 200, 319]
# Sum of True Negative:  1590

# %% [markdown]
# ## Check TP + FP + FN + TN = Test set

# %%
l = len(test_labels)
for i in range(NUM_CLASSES):
    print(TruePositive[i] + FalsePositive[i] + FalseNegative[i] + TrueNegative[i] == l)
# Out:
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ## PYCM

# %%
# !pip3 install pycm==3.0
# Out:
# Collecting pycm==3.0
#   Downloading https://files.pythonhosted.org/packages/07/e0/de92301a06bf5e2d24e04edc178ee457b49dbad2606c3252949222110f4d/pycm-3.0-py2.py3-none-any.whl (61kB)
#      |████████████████████████████████| 71kB 4.3MB/s
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pycm==3.0) (1.19.5)
# Collecting art>=1.8
#   Downloading https://files.pythonhosted.org/packages/83/37/c28d69ba1005889e8ff9633b8e7eccaaddc03549058a51ef5f51853cf183/art-5.1-py2.py3-none-any.whl (567kB)
#      |████████████████████████████████| 573kB 8.7MB/s
# Installing collected packages: art, pycm
# Successfully installed art-5.1 pycm-3.0

# %%
from pycm import *

# %%
py_cm = ConfusionMatrix(actual_vector=test_labels, predict_vector=y_pred)

# %%
py_cm.classes
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
py_cm.table
# Out:
# {0: {0: 17, 1: 5, 2: 7, 3: 1, 4: 3, 5: 0},
#  1: {0: 2, 1: 41, 2: 5, 3: 0, 4: 4, 5: 0},
#  2: {0: 3, 1: 5, 2: 86, 3: 1, 4: 15, 5: 0},
#  3: {0: 1, 1: 0, 2: 1, 3: 10, 4: 0, 5: 0},
#  4: {0: 4, 1: 2, 2: 17, 3: 2, 4: 87, 5: 0},
#  5: {0: 0, 1: 0, 2: 1, 3: 1, 4: 0, 5: 13}}

# %%
print(py_cm)
# Out:
# Predict  0        1        2        3        4        5
# Actual
# 0        17       5        7        1        3        0
#
# 1        2        41       5        0        4        0
#
# 2        3        5        86       1        15       0
#
# 3        1        0        1        10       0        0
#
# 4        4        2        17       2        87       0
#
# 5        0        0        1        1        0        13
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (0.71471,0.80625)
# ACC Macro                                                         0.92016
# ARI                                                               0.47343
# AUNP                                                              0.8356
# AUNU                                                              0.85279
# Bangdiwala B                                                      0.5912
# Bennett S                                                         0.71257
# CBA                                                               0.72232
# CSI                                                               0.52755
# Chi-Squared                                                       887.90002
# Chi-Squared DF                                                    25
# Conditional Entropy                                               1.12317
# Cramer V                                                          0.72916
# Cross Entropy                                                     2.18332
# F1 Macro                                                          0.76033
# F1 Micro                                                          0.76048
# FNR Macro                                                         0.23963
# FNR Micro                                                         0.23952
# FPR Macro                                                         0.0548
# FPR Micro                                                         0.0479
# Gwet AC1                                                          0.71894
# Hamming Loss                                                      0.23952
# Joint Entropy                                                     3.30063
# KL Divergence                                                     0.00585
# Kappa                                                             0.67595
# Kappa 95% CI                                                      (0.61402,0.73787)
# Kappa No Prevalence                                               0.52096
# Kappa Standard Error                                              0.03159
# Kappa Unbiased                                                    0.67584
# Krippendorff Alpha                                                0.67633
# Lambda A                                                          0.63964
# Lambda B                                                          0.63134
# Mutual Information                                                1.03229
# NIR                                                               0.33533
# Overall ACC                                                       0.76048
# Overall CEN                                                       0.32412
# Overall J                                                         (3.75006,0.62501)
# Overall MCC                                                       0.6764
# Overall MCEN                                                      0.4451
# Overall RACC                                                      0.26086
# Overall RACCU                                                     0.2611
# P-Value                                                           0.0
# PPV Macro                                                         0.76718
# PPV Micro                                                         0.76048
# Pearson C                                                         0.85244
# Phi-Squared                                                       2.65838
# RCI                                                               0.47408
# RR                                                                55.66667
# Reference Entropy                                                 2.17746
# Response Entropy                                                  2.15545
# SOA1(Landis & Koch)                                               Substantial
# SOA2(Fleiss)                                                      Intermediate to Good
# SOA3(Altman)                                                      Good
# SOA4(Cicchetti)                                                   Good
# SOA5(Cramer)                                                      Strong
# SOA6(Matthews)                                                    Moderate
# Scott PI                                                          0.67584
# Standard Error                                                    0.02335
# TNR Macro                                                         0.9452
# TNR Micro                                                         0.9521
# TPR Macro                                                         0.76037
# TPR Micro                                                         0.76048
# Zero-one Loss                                                     80
#
# Class Statistics :
#
# Classes                                                           0             1             2             3             4             5
# ACC(Accuracy)                                                     0.92216       0.93114       0.83533       0.97904       0.85928       0.99401
# AGF(Adjusted F-score)                                             0.71324       0.86842       0.82596       0.88724       0.8343        0.94126
# AGM(Adjusted geometric mean)                                      0.82946       0.90941       0.83715       0.94439       0.86224       0.96468
# AM(Difference between automatic and manual classification)        -6            1             7             3             -3            -2
# AUC(Area under the ROC curve)                                     0.74096       0.87295       0.82171       0.9089        0.83884       0.93333
# AUCI(AUC value interpretation)                                    Good          Very Good     Very Good     Excellent     Very Good     Excellent
# AUPR(Area under the PR curve)                                     0.57239       0.78102       0.75843       0.75          0.78748       0.93333
# BCD(Bray-Curtis dissimilarity)                                    0.00898       0.0015        0.01048       0.00449       0.00449       0.00299
# BM(Informedness or bookmaker informedness)                        0.48193       0.74591       0.64343       0.81781       0.67769       0.86667
# CEN(Confusion entropy)                                            0.51581       0.30848       0.33782       0.3488        0.29039       0.10337
# DOR(Diagnostic odds ratio)                                        30.91875      83.86364      22.30914      317.0         31.63636      None
# DP(Discriminant power)                                            0.8216        1.06052       0.74346       1.37891       0.8271        None
# DPI(Discriminant power interpretation)                            Poor          Limited       Poor          Limited       Poor          None
# ERR(Error rate)                                                   0.07784       0.06886       0.16467       0.02096       0.14072       0.00599
# F0.5(F0.5 score)                                                  0.60284       0.77652       0.74394       0.69444       0.7938        0.97015
# F1(F1 score - harmonic mean of precision and sensitivity)         0.56667       0.78095       0.75771       0.74074       0.78733       0.92857
# F2(F2 score)                                                      0.53459       0.78544       0.77199       0.79365       0.78097       0.89041
# FDR(False discovery rate)                                         0.37037       0.22642       0.26496       0.33333       0.20183       0.0
# FN(False negative/miss/type 2 error)                              16            11            24            2             25            2
# FNR(Miss rate or false negative rate)                             0.48485       0.21154       0.21818       0.16667       0.22321       0.13333
# FOR(False omission rate)                                          0.05212       0.03915       0.1106        0.00627       0.11111       0.00623
# FP(False positive/type 1 error/false alarm)                       10            12            31            5             22            0
# FPR(Fall-out or false positive rate)                              0.03322       0.04255       0.13839       0.01553       0.0991        0.0
# G(G-measure geometric mean of precision and sensitivity)          0.56952       0.78099       0.75807       0.74536       0.7874        0.93095
# GI(Gini index)                                                    0.48193       0.74591       0.64343       0.81781       0.67769       0.86667
# GM(G-mean geometric mean of specificity and sensitivity)          0.70572       0.86886       0.82074       0.90576       0.83654       0.93095
# IBA(Index of balanced accuracy)                                   0.27311       0.62734       0.61987       0.6964        0.61295       0.75111
# ICSI(Individual classification success index)                     0.14478       0.56205       0.51686       0.5           0.57495       0.86667
# IS(Information score)                                             2.67189       2.3129        1.15824       4.21378       1.25111       4.47681
# J(Jaccard index)                                                  0.39535       0.64062       0.60993       0.58824       0.64925       0.86667
# LS(Lift score)                                                    6.37262       4.9688        2.23186       18.55556      2.38024       22.26667
# MCC(Matthews correlation coefficient)                             0.52756       0.74015       0.63386       0.7349        0.68235       0.92804
# MCCI(Matthews correlation coefficient interpretation)             Moderate      Strong        Moderate      Strong        Moderate      Very Strong
# MCEN(Modified confusion entropy)                                  0.63225       0.42883       0.4632        0.47124       0.40271       0.15681
# MK(Markedness)                                                    0.57751       0.73444       0.62444       0.6604        0.68705       0.99377
# N(Condition negative)                                             301           282           224           322           222           319
# NLR(Negative likelihood ratio)                                    0.50151       0.22094       0.25323       0.1693        0.24777       0.13333
# NLRI(Negative likelihood ratio interpretation)                    Negligible    Poor          Poor          Fair          Poor          Fair
# NPV(Negative predictive value)                                    0.94788       0.96085       0.8894        0.99373       0.88889       0.99377
# OC(Overlap coefficient)                                           0.62963       0.78846       0.78182       0.83333       0.79817       1.0
# OOC(Otsuka-Ochiai coefficient)                                    0.56952       0.78099       0.75807       0.74536       0.7874        0.93095
# OP(Optimized precision)                                           0.6174        0.83435       0.78678       0.8959        0.7853        0.92258
# P(Condition positive or support)                                  33            52            110           12            112           15
# PLR(Positive likelihood ratio)                                    15.50606      18.52885      5.64927       53.66667      7.83847       None
# PLRI(Positive likelihood ratio interpretation)                    Good          Good          Fair          Good          Fair          None
# POP(Population)                                                   334           334           334           334           334           334
# PPV(Precision or positive predictive value)                       0.62963       0.77358       0.73504       0.66667       0.79817       1.0
# PRE(Prevalence)                                                   0.0988        0.15569       0.32934       0.03593       0.33533       0.04491
# Q(Yule Q - coefficient of colligation)                            0.93734       0.97643       0.9142        0.99371       0.93872       None
# QI(Yule Q interpretation)                                         Strong        Strong        Strong        Strong        Strong        None
# RACC(Random accuracy)                                             0.00799       0.02471       0.11537       0.00161       0.10943       0.00175
# RACCU(Random accuracy unbiased)                                   0.00807       0.02471       0.11548       0.00163       0.10945       0.00176
# TN(True negative/correct rejection)                               291           270           193           317           200           319
# TNR(Specificity or true negative rate)                            0.96678       0.95745       0.86161       0.98447       0.9009        1.0
# TON(Test outcome negative)                                        307           281           217           319           225           321
# TOP(Test outcome positive)                                        27            53            117           15            109           13
# TP(True positive/hit)                                             17            41            86            10            87            13
# TPR(Sensitivity, recall, hit rate, or true positive rate)         0.51515       0.78846       0.78182       0.83333       0.77679       0.86667
# Y(Youden index)                                                   0.48193       0.74591       0.64343       0.81781       0.67769       0.86667
# dInd(Distance index)                                              0.48599       0.21578       0.25837       0.16739       0.24422       0.13333
# sInd(Similarity index)                                            0.65636       0.84742       0.8173        0.88164       0.82731       0.90572

# %% [markdown]
# ### Average AUC

# %%
AV_AUC = (py_cm.AUC[0] + py_cm.AUC[1] + py_cm.AUC[2] + py_cm.AUC[3] + py_cm.AUC[4] + py_cm.AUC[5])/len(py_cm.AUC)

# %%
print('Average AUC: ', AV_AUC)
# Out:
# Average AUC:  0.852785105026079

# %% [markdown]
# ### Average Sensitivity

# %%
AV_Sens = (py_cm.TPR[0] + py_cm.TPR[1] + py_cm.TPR[2] + py_cm.TPR[3] + py_cm.TPR[4] + py_cm.TPR[5])/len(py_cm.TPR)

# %%
print('Average Sensitivity: ', AV_Sens)
# Out:
# Average Sensitivity:  0.7603694916194916

# %% [markdown]
# ### Average Specificity

# %%
AV_Spec = (py_cm.TNR[0] + py_cm.TNR[1] + py_cm.TNR[2] + py_cm.TNR[3] + py_cm.TNR[4] + py_cm.TNR[5])/len(py_cm.TNR)

# %%
print('Average Specificity: ', AV_Spec)
# Out:
# Average Specificity:  0.9452007184326661

# %% [markdown]
# ## Grad-CAM

# %%
last_conv2d = 'block5_conv3'

# %% [markdown]
# ### AKIEC

# %%
akiec_img = '/content/6_classes_HAM10000_split_Ver2/images/pca-aug_train/akiec/ISIC_0026492.jpg'

# %%
 gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, akiec_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.993
# 	bkl            	(2)	with probability 0.004
# 	akiec          	(0)	with probability 0.002
# 	df             	(3)	with probability 0.000
# 	bcc            	(1)	with probability 0.000
# Explanation for 'mel'

# %% [markdown]
# ### BCC

# %%
bcc_img = '/content/6_classes_HAM10000_split_Ver2/images/pca-aug_train/bcc/ISIC_0024332.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, bcc_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.661
# 	akiec          	(0)	with probability 0.160
# 	bcc            	(1)	with probability 0.131
# 	bkl            	(2)	with probability 0.045
# 	df             	(3)	with probability 0.003
# Explanation for 'mel'

# %% [markdown]
# ### BKL

# %%
bkl_img = '/content/6_classes_HAM10000_split_Ver2/images/pca-aug_train/bkl/ISIC_0025548.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, bkl_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.794
# 	bkl            	(2)	with probability 0.196
# 	akiec          	(0)	with probability 0.010
# 	df             	(3)	with probability 0.000
# 	bcc            	(1)	with probability 0.000
# Explanation for 'mel'

# %% [markdown]
# ### DF

# %%
df_img = '/content/6_classes_HAM10000_split_Ver2/images/cc_val/df/ISIC_0033626.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, df_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.651
# 	df             	(3)	with probability 0.328
# 	akiec          	(0)	with probability 0.019
# 	bkl            	(2)	with probability 0.002
# 	bcc            	(1)	with probability 0.000
# Explanation for 'mel'

# %% [markdown]
# ### MEL

# %%
mel_img = '/content/6_classes_HAM10000_split_Ver2/images/pca-aug_train/mel/ISIC_0024516.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, mel_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.997
# 	akiec          	(0)	with probability 0.002
# 	bkl            	(2)	with probability 0.001
# 	df             	(3)	with probability 0.000
# 	bcc            	(1)	with probability 0.000
# Explanation for 'mel'

# %% [markdown]
# ### VASC

# %%
vasc_img = '/content/6_classes_HAM10000_split_Ver2/images/cc_test/vasc/ISIC_0025452.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, vasc_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	vasc           	(5)	with probability 1.000
# 	mel            	(4)	with probability 0.000
# 	bcc            	(1)	with probability 0.000
# 	akiec          	(0)	with probability 0.000
# 	df             	(3)	with probability 0.000
# Explanation for 'vasc'

# %% [markdown]
# # Download Model

# %%
from google.colab import files

# %%
files.download('/content/HAM10000_VGG16_Ver2_model.h5')
