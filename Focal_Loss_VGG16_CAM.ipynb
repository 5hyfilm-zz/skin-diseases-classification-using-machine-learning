# %% [markdown]
# <a href="https://colab.research.google.com/github/filmerxyz/JSTP-22_SkinDiseaseClassificationUsingMachineLearning/blob/master/Focal_Loss_VGG16_CAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Check GPU**

# %%
# !nvidia-smi
# Out:
# Mon May 18 03:50:18 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# # **Import Libraries**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import models
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers

from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import shutil
import os
from os.path import join

from ham10000_utils_functions import plot_confusion_matrix, normalize, deprocess_image, my_decode_predictions, guided_backprop, grad_cam, compute_saliency
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # **Clone Data**

# %%
# !git clone https://github.com/EvilPickle-PCSHSPT/ham10000-with-one-image-folder
# Out:
# Cloning into 'ham10000-with-one-image-folder'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 10045 (delta 4), reused 7 (delta 2), pack-reused 10036
# Receiving objects: 100% (10045/10045), 2.57 GiB | 44.41 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# Checking out files: 100% (10022/10022), done.

# %% [markdown]
# # **Constant Variables**

# %%
IMG_WIDTH = 224
IMG_HEIGHT = 224
EPOCHS = 30
BATCH_SIZE = 32
NUM_CLASSES = 7

LR = 3e-5 # Learning rate

# %% [markdown]
# # **Prepare Data**

# %%
data=pd.read_csv('/content/ham10000-with-one-image-folder/HAM10000_metadata.csv')
data['image_full_name']=data['image_id']+'.jpg'
X=data[['image_full_name','dx','lesion_id']]

# %%
data.head(5)
# Out:
#      lesion_id      image_id   dx  ...   sex  localization   image_full_name
# 0  HAM_0000118  ISIC_0027419  bkl  ...  male         scalp  ISIC_0027419.jpg
# 1  HAM_0000118  ISIC_0025030  bkl  ...  male         scalp  ISIC_0025030.jpg
# 2  HAM_0002730  ISIC_0026769  bkl  ...  male         scalp  ISIC_0026769.jpg
# 3  HAM_0002730  ISIC_0025661  bkl  ...  male         scalp  ISIC_0025661.jpg
# 4  HAM_0001466  ISIC_0031633  bkl  ...  male           ear  ISIC_0031633.jpg
#
# [5 rows x 8 columns]

# %% [markdown]
# ### **Split Data**

# %%
from sklearn.model_selection import train_test_split
Y=X.pop('dx').to_frame()
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.1, random_state=42)
X_train,X_val,y_train,y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=42)

# %%
train = pd.concat([X_train,y_train],axis=1)
val = pd.concat([X_val,y_val],axis=1)
test = pd.concat([X_test,y_test],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(val['dx'])
name_as_indexes_train = encoder.transform(val['dx']) 
val['label'] = name_as_indexes_train

# %%
encoder = LabelEncoder()
encoder.fit(test['dx'])
name_as_indexes_test = encoder.transform(test['dx']) 
test['label'] = name_as_indexes_test

# %%
encoder=LabelEncoder()
encoder.fit(test['dx'])
name_as_indexes_test = encoder.transform(test['dx']) 
test['label'] = name_as_indexes_test

# %% [markdown]
# ### **Data Augmentation**

# %%
train_generator = ImageDataGenerator(rescale = 1./255,
                                     rotation_range=360,  
                                     zoom_range = 0.3,
                                     horizontal_flip=True,
                                     vertical_flip=True,
                                     fill_mode='reflect')
                                    
test_generator=ImageDataGenerator(rescale = 1./255)
test_generator=ImageDataGenerator(rescale = 1./255)

# %%
train_data= train_generator.flow_from_dataframe(dataframe=train,x_col="image_full_name",y_col="dx",
                                                directory='/content/ham10000-with-one-image-folder/HAM1000_images',
                                                shuffle=True,batch_size=32,class_mode="categorical",target_size=(IMG_WIDTH,IMG_HEIGHT))

val_data= test_generator.flow_from_dataframe(dataframe=val,x_col="image_full_name",y_col="dx",
                                              directory='/content/ham10000-with-one-image-folder/HAM1000_images',
                                              shuffle=True,batch_size=32,class_mode='categorical',target_size=(IMG_WIDTH,IMG_HEIGHT))

test_data= test_generator.flow_from_dataframe(dataframe=test,x_col="image_full_name",y_col="dx",
                                              directory='/content/ham10000-with-one-image-folder/HAM1000_images',
                                              shuffle=False,batch_size=1,class_mode=None,target_size=(IMG_WIDTH,IMG_HEIGHT))
# Out:
# Found 6309 validated image filenames belonging to 7 classes.
# Found 2704 validated image filenames belonging to 7 classes.
# Found 1002 validated image filenames.

# %% [markdown]
# # **Focal Loss**

# %% [markdown]
# https://github.com/mkocabas/focal-loss-keras

# %% [markdown]
# $$\text{FL}(p_t) = -\alpha_t (1 - p_t)^{\gamma} \, \text{log}(p_t)$$

# %%
def focal_loss(gamma=2., alpha=.25):
	def focal_loss_fixed(y_true, y_pred):
		pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
		pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
		return -K.mean(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1)) - K.mean((1 - alpha) * K.pow(pt_0, gamma) * K.log(1. - pt_0))
	return focal_loss_fixed

# %% [markdown]
# # **Build Model**

# %% [markdown]
# ### **Use VGG16 + fine tuning**

# %%
def build_model():
  base_model = tf.keras.applications.VGG16(include_top=False, input_shape=(IMG_WIDTH, IMG_HEIGHT, 3), weights='imagenet')
  base_model.trainable = True

  for layer in base_model.layers[:15]: # Fixed first 12 layers
    layer.trainable = False

  average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
  fc_layer = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.0001))(average_pooling_layer)
  fc_layer = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.0001))(fc_layer)
  bn_layer = tf.keras.layers.BatchNormalization()(fc_layer)
  dropout_layer = tf.keras.layers.Dropout(0.25)(bn_layer)
  prediction_layer = tf.keras.layers.Dense(units=NUM_CLASSES, activation='softmax', name='prediction')(dropout_layer)
  model = tf.keras.models.Model(inputs=base_model.input, outputs=prediction_layer)
  
  model.compile(optimizer=Adam(LR), loss=[focal_loss(alpha=.25, gamma=2)], metrics=['accuracy'])
  return model

# %%
model = build_model()

# %% [markdown]
# ### **Architecture**

# %%
model.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d_10  (None, 512)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_21 (Dense)             (None, 32)                2080
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 32)                128
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 32)                0
# _________________________________________________________________
# prediction (Dense)           (None, 7)                 231
# =================================================================
# Total params: 14,749,959
# Trainable params: 7,114,631
# Non-trainable params: 7,635,328
# _________________________________________________________________

# %% [markdown]
# ### **Callbacks**

# %%
model_path = '/content/vgg16_model.h5'

# %%
checkpoint = ModelCheckpoint(model_path, monitor='val_loss', verbose=1,
                             save_best_only=True, mode='max')

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

# %%
reduce_plateau = ReduceLROnPlateau(monitor='val_acc', patience=3, verbose=1, factor=.5, min_lr=0.00001)

# %%
cb_list = [checkpoint, early_stop, reduce_plateau]

# %% [markdown]
# ### **Training**

# %%
history = model.fit_generator(generator=train_data,
                            steps_per_epoch=train_data.samples//train_data.batch_size,
                            validation_data=val_data,
                            verbose=1,
                            validation_steps=val_data.samples//val_data.batch_size,
                            epochs=EPOCHS,
                            callbacks=cb_list)
# Out:
# Epoch 1/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0649 - acc: 0.4093Epoch 1/30
#  84/197 [===========>..................] - ETA: 34s - loss: 0.0529 - acc: 0.6871
# Epoch 00001: val_loss improved from -inf to 0.05291, saving model to /content/vgg16_model.h5
# 197/197 [==============================] - 141s 716ms/step - loss: 0.0648 - acc: 0.4102 - val_loss: 0.0529 - val_acc: 0.6871
# Epoch 2/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0570 - acc: 0.5211Epoch 1/30
#  84/197 [===========>..................] - ETA: 34s - loss: 0.0543 - acc: 0.6068
# Epoch 00002: val_loss improved from 0.05291 to 0.05432, saving model to /content/vgg16_model.h5
# 197/197 [==============================] - 137s 695ms/step - loss: 0.0569 - acc: 0.5216 - val_loss: 0.0543 - val_acc: 0.6068
# Epoch 3/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0542 - acc: 0.5580Epoch 1/30
#  84/197 [===========>..................] - ETA: 35s - loss: 0.0603 - acc: 0.4833
# Epoch 00003: val_loss improved from 0.05432 to 0.06029, saving model to /content/vgg16_model.h5
# 197/197 [==============================] - 137s 696ms/step - loss: 0.0542 - acc: 0.5584 - val_loss: 0.0603 - val_acc: 0.4833
# Epoch 4/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0491 - acc: 0.6341Epoch 1/30
#  84/197 [===========>..................] - ETA: 35s - loss: 0.0491 - acc: 0.6551
# Epoch 00004: val_loss did not improve from 0.06029
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
# 197/197 [==============================] - 137s 693ms/step - loss: 0.0491 - acc: 0.6344 - val_loss: 0.0491 - val_acc: 0.6551
# Epoch 5/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0465 - acc: 0.6597Epoch 1/30
#  84/197 [===========>..................] - ETA: 35s - loss: 0.0450 - acc: 0.6853
# Epoch 00005: val_loss did not improve from 0.06029
# 197/197 [==============================] - 136s 692ms/step - loss: 0.0465 - acc: 0.6596 - val_loss: 0.0450 - val_acc: 0.6853
# Epoch 6/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0448 - acc: 0.6701Epoch 1/30
#  84/197 [===========>..................] - ETA: 36s - loss: 0.0426 - acc: 0.7128
# Epoch 00006: val_loss did not improve from 0.06029
# 197/197 [==============================] - 136s 693ms/step - loss: 0.0447 - acc: 0.6702 - val_loss: 0.0426 - val_acc: 0.7128
# Epoch 7/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0439 - acc: 0.6807Epoch 1/30
#  84/197 [===========>..................] - ETA: 36s - loss: 0.0383 - acc: 0.7377
# Epoch 00007: val_loss did not improve from 0.06029
# 197/197 [==============================] - 136s 689ms/step - loss: 0.0438 - acc: 0.6807 - val_loss: 0.0383 - val_acc: 0.7377
# Epoch 8/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0423 - acc: 0.6831Epoch 1/30
#  84/197 [===========>..................] - ETA: 36s - loss: 0.0362 - acc: 0.7366
# Epoch 00008: val_loss did not improve from 0.06029
# 197/197 [==============================] - 136s 689ms/step - loss: 0.0422 - acc: 0.6831 - val_loss: 0.0362 - val_acc: 0.7366
# Epoch 9/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0413 - acc: 0.6937Epoch 1/30
#  84/197 [===========>..................] - ETA: 37s - loss: 0.0403 - acc: 0.7247
# Epoch 00009: val_loss did not improve from 0.06029
# 197/197 [==============================] - 135s 687ms/step - loss: 0.0412 - acc: 0.6936 - val_loss: 0.0403 - val_acc: 0.7247
# Epoch 10/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0401 - acc: 0.7066Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0371 - acc: 0.7318
# Epoch 00010: val_loss did not improve from 0.06029
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1e-05.
# 197/197 [==============================] - 135s 687ms/step - loss: 0.0401 - acc: 0.7067 - val_loss: 0.0371 - val_acc: 0.7318
# Epoch 11/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0390 - acc: 0.7108Epoch 1/30
#  84/197 [===========>..................] - ETA: 37s - loss: 0.0362 - acc: 0.7500
# Epoch 00011: val_loss did not improve from 0.06029
# 197/197 [==============================] - 135s 686ms/step - loss: 0.0390 - acc: 0.7103 - val_loss: 0.0362 - val_acc: 0.7500
# Epoch 12/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0378 - acc: 0.7248Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0367 - acc: 0.7374
# Epoch 00012: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 682ms/step - loss: 0.0378 - acc: 0.7248 - val_loss: 0.0367 - val_acc: 0.7374
# Epoch 13/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0376 - acc: 0.7241Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0344 - acc: 0.7533
# Epoch 00013: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 680ms/step - loss: 0.0376 - acc: 0.7238 - val_loss: 0.0344 - val_acc: 0.7533
# Epoch 14/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0370 - acc: 0.7315Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0357 - acc: 0.7560
# Epoch 00014: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 679ms/step - loss: 0.0370 - acc: 0.7312 - val_loss: 0.0357 - val_acc: 0.7560
# Epoch 15/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0369 - acc: 0.7310Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0346 - acc: 0.7574
# Epoch 00015: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 681ms/step - loss: 0.0368 - acc: 0.7309 - val_loss: 0.0346 - val_acc: 0.7574
# Epoch 16/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0353 - acc: 0.7353Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0299 - acc: 0.7719
# Epoch 00016: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 678ms/step - loss: 0.0353 - acc: 0.7355 - val_loss: 0.0299 - val_acc: 0.7719
# Epoch 17/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0348 - acc: 0.7464Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0508 - acc: 0.5971
# Epoch 00017: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 680ms/step - loss: 0.0348 - acc: 0.7456 - val_loss: 0.0508 - val_acc: 0.5971
# Epoch 18/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0346 - acc: 0.7459Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0325 - acc: 0.7597
# Epoch 00018: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 678ms/step - loss: 0.0346 - acc: 0.7461 - val_loss: 0.0325 - val_acc: 0.7597
# Epoch 19/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0334 - acc: 0.7608Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0315 - acc: 0.7574
# Epoch 00019: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 678ms/step - loss: 0.0334 - acc: 0.7609 - val_loss: 0.0315 - val_acc: 0.7574
# Epoch 20/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0334 - acc: 0.7468Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0305 - acc: 0.7753
# Epoch 00020: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 680ms/step - loss: 0.0334 - acc: 0.7469 - val_loss: 0.0305 - val_acc: 0.7753
# Epoch 21/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0323 - acc: 0.7564Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0325 - acc: 0.7574
# Epoch 00021: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 679ms/step - loss: 0.0323 - acc: 0.7572 - val_loss: 0.0325 - val_acc: 0.7574
# Epoch 22/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0319 - acc: 0.7604Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0399 - acc: 0.6938
# Epoch 00022: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 680ms/step - loss: 0.0319 - acc: 0.7604 - val_loss: 0.0399 - val_acc: 0.6938
# Epoch 23/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0316 - acc: 0.7638Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0380 - acc: 0.7143
# Epoch 00023: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 679ms/step - loss: 0.0316 - acc: 0.7641 - val_loss: 0.0380 - val_acc: 0.7143
# Epoch 24/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0311 - acc: 0.7636Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0297 - acc: 0.7731
# Epoch 00024: val_loss did not improve from 0.06029
# 197/197 [==============================] - 135s 683ms/step - loss: 0.0311 - acc: 0.7636 - val_loss: 0.0297 - val_acc: 0.7731
# Epoch 25/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0305 - acc: 0.7713Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0286 - acc: 0.7708
# Epoch 00025: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 678ms/step - loss: 0.0305 - acc: 0.7717 - val_loss: 0.0286 - val_acc: 0.7708
# Epoch 26/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0301 - acc: 0.7766Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0285 - acc: 0.7649
# Epoch 00026: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 679ms/step - loss: 0.0301 - acc: 0.7766 - val_loss: 0.0285 - val_acc: 0.7649
# Epoch 27/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0292 - acc: 0.7829Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0289 - acc: 0.7604
# Epoch 00027: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 679ms/step - loss: 0.0292 - acc: 0.7827 - val_loss: 0.0289 - val_acc: 0.7604
# Epoch 28/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0290 - acc: 0.7755Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0295 - acc: 0.7708
# Epoch 00028: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 679ms/step - loss: 0.0290 - acc: 0.7754 - val_loss: 0.0295 - val_acc: 0.7708
# Epoch 29/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0287 - acc: 0.7795Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0285 - acc: 0.7783
# Epoch 00029: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 680ms/step - loss: 0.0287 - acc: 0.7800 - val_loss: 0.0285 - val_acc: 0.7783
# Epoch 30/30
# 196/197 [============================>.] - ETA: 0s - loss: 0.0283 - acc: 0.7829Epoch 1/30
#  84/197 [===========>..................] - ETA: 38s - loss: 0.0283 - acc: 0.7701
# Epoch 00030: val_loss did not improve from 0.06029
# 197/197 [==============================] - 134s 680ms/step - loss: 0.0284 - acc: 0.7829 - val_loss: 0.0283 - val_acc: 0.7701

# %%
model.save_weights('/content/vgg16_weights.h5')

# %% [markdown]
# # **Accuracy and Loss Graph**

# %% [markdown]
# ### **Accuracy**

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('accuracy')
plt.show()

# %% [markdown]
# ### **Loss**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('loss')
plt.show()

# %% [markdown]
# # **Evaluate**

# %%
test_data.reset()
predictions = model.predict_generator(test_data, steps=test_data.samples/test_data.batch_size,verbose=1)
y_pred= np.argmax(predictions, axis=1)
# Out:
# 1002/1002 [==============================] - 13s 13ms/step

# %% [markdown]
# ### **Classification Report**

# %%
Y_pred = predictions
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
print(confusion_matrix(name_as_indexes_test, y_pred))
print('Classification Report')
classes_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
print(classification_report(name_as_indexes_test, y_pred, target_names=classes_names))
# Out:
# Confusion Matrix
# [[ 13   8  14   0   1   5   0]
#  [  4  31   7   0   1   3   1]
#  [  3   5  71   1  11  34   0]
#  [  1   4   4   1   0   5   0]
#  [  1   1  31   0  42  34   1]
#  [  1  15  34   2  11 583   3]
#  [  0   1   0   0   0   2  12]]
# Classification Report
#               precision    recall  f1-score   support
#
#        akiec       0.57      0.32      0.41        41
#          bcc       0.48      0.66      0.55        47
#          bkl       0.44      0.57      0.50       125
#           df       0.25      0.07      0.11        15
#          mel       0.64      0.38      0.48       110
#           nv       0.88      0.90      0.89       649
#         vasc       0.71      0.80      0.75        15
#
#     accuracy                           0.75      1002
#    macro avg       0.56      0.53      0.53      1002
# weighted avg       0.75      0.75      0.74      1002

# %% [markdown]
# ### **Confusion Matrix**

# %%
cm = (confusion_matrix(name_as_indexes_test, y_pred))

plot_confusion_matrix(cm, classes_names)
# Out:
# Confusion matrix, without normalization
# [[ 13   8  14   0   1   5   0]
#  [  4  31   7   0   1   3   1]
#  [  3   5  71   1  11  34   0]
#  [  1   4   4   1   0   5   0]
#  [  1   1  31   0  42  34   1]
#  [  1  15  34   2  11 583   3]
#  [  0   1   0   0   0   2  12]]

# %% [markdown]
# ### **Sensitivity & Specificity**

# %%
total = sum(sum(cm))
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])

# %%
print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))
# Out:
# sensitivity: 0.6190
# specificity: 0.8857

# %% [markdown]
# # **Grad-CAM**

# %%
last_conv2d = 'block5_conv3'

# %% [markdown]
# ### **AKIEC**

# %%
akiec_img = '/content/ham10000-with-one-image-folder/HAM1000_images/ISIC_0026492.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(model, model, akiec_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.828
# 	bkl            	(2)	with probability 0.092
# 	df             	(3)	with probability 0.048
# 	akiec          	(0)	with probability 0.012
# 	bcc            	(1)	with probability 0.012
# Explanation for 'mel'

# %% [markdown]
# ### **BCC**

# %%
bcc_img = '/content/ham10000-with-one-image-folder/HAM1000_images/ISIC_0024332.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(model, model, bcc_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.380
# 	bkl            	(2)	with probability 0.257
# 	akiec          	(0)	with probability 0.103
# 	bcc            	(1)	with probability 0.087
# 	df             	(3)	with probability 0.082
# Explanation for 'mel'

# %% [markdown]
# ### **BKL**

# %%
bkl_img = '/content/ham10000-with-one-image-folder/HAM1000_images/ISIC_0025548.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(model, model, bkl_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.788
# 	bkl            	(2)	with probability 0.152
# 	df             	(3)	with probability 0.032
# 	bcc            	(1)	with probability 0.012
# 	vasc           	(6)	with probability 0.009
# Explanation for 'mel'

# %% [markdown]
# ### **DF**

# %%
df_img = '/content/ham10000-with-one-image-folder/HAM1000_images/ISIC_0033626.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(model, model, df_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	nv             	(5)	with probability 0.418
# 	mel            	(4)	with probability 0.230
# 	df             	(3)	with probability 0.159
# 	vasc           	(6)	with probability 0.062
# 	bcc            	(1)	with probability 0.052
# Explanation for 'nv'

# %% [markdown]
# ### **MEL**

# %%
mel_img = '/content/ham10000-with-one-image-folder/HAM1000_images/ISIC_0024516.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(model, model, mel_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.545
# 	df             	(3)	with probability 0.114
# 	nv             	(5)	with probability 0.108
# 	bcc            	(1)	with probability 0.089
# 	bkl            	(2)	with probability 0.086
# Explanation for 'mel'

# %% [markdown]
# ### **NV**

# %%
nv_img = '/content/ham10000-with-one-image-folder/HAM1000_images/ISIC_0024349.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(model, model, nv_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	nv             	(5)	with probability 0.364
# 	mel            	(4)	with probability 0.309
# 	df             	(3)	with probability 0.116
# 	bcc            	(1)	with probability 0.101
# 	bkl            	(2)	with probability 0.043
# Explanation for 'nv'

# %% [markdown]
# ### **VASC**

# %%
vasc_img = '/content/ham10000-with-one-image-folder/HAM1000_images/ISIC_0025452.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(model, model, vasc_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	vasc           	(6)	with probability 0.976
# 	akiec          	(0)	with probability 0.021
# 	df             	(3)	with probability 0.002
# 	bkl            	(2)	with probability 0.001
# 	bcc            	(1)	with probability 0.000
# Explanation for 'vasc'

# %% [markdown]
# # **Download Model**

# %%
from google.colab import files

# %%
files.download('/content/Focal-Loss_VGG16_model.h5')
files.download('/content/Focal-Loss_VGG16_weights.h5')
