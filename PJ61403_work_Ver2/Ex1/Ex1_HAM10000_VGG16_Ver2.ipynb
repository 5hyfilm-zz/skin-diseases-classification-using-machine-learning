# %% [markdown]
# <a href="https://colab.research.google.com/github/fxlmer/JSTP22_Skin-Diseases-Classification-Using-Machine-Learning/blob/master/Ex1_HAM10000_VGG16_Ver2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Check GPU

# %%
# !nvidia-smi
# Out:
# Sat Feb 20 07:28:40 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P8    12W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import models
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Activation, Flatten, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
from tensorflow.keras.utils import Sequence
from imblearn.over_sampling import RandomOverSampler
from imblearn.keras import balanced_batch_generator

from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight, compute_sample_weight, compute_class_weight
from sklearn.metrics import balanced_accuracy_score, classification_report, confusion_matrix

import pandas as pd
import numpy as np
import os
import math
import itertools
from PIL import Image
from matplotlib import pyplot as plt

from ham10000_6classes_utils_functions_Ver2 import *
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# # Hyperparameters

# %%
IMG_WIDTH = 224
IMG_HEIGHT = 224
EPOCHS = 100
BATCH_SIZE = 32
NUM_CLASSES = 6

LR = 1e-5 # Learning rate

# %% [markdown]
# # Data Preparation

# %%
# !git clone https://github.com/EvilPickle-PCSHSPT/6_classes_HAM10000_split_Ver2
# Out:
# fatal: destination path '6_classes_HAM10000_split_Ver2' already exists and is not an empty directory.

# %%
train_path = '/content/6_classes_HAM10000_split_Ver2/images/pca-aug_train' 
val_path = '/content/6_classes_HAM10000_split_Ver2/images/cc_val'
test_path = '/content/6_classes_HAM10000_split_Ver2/images/cc_test'

# %% [markdown]
# # Data Augmentation

# %%
train_aug = ImageDataGenerator(rescale=1./255,
                               rotation_range=360,
                               zoom_range=0.1,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               horizontal_flip=True,
                               vertical_flip=True,
                               fill_mode='reflect')

val_aug = ImageDataGenerator(rescale=1./255)

test_aug = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_aug.flow_from_directory(train_path, 
                                                target_size=(IMG_WIDTH, IMG_HEIGHT), 
                                                batch_size=BATCH_SIZE, 
                                                shuffle=True,
                                                class_mode='categorical') 

val_generator = val_aug.flow_from_directory(val_path, 
                                              target_size=(IMG_WIDTH, IMG_HEIGHT), 
                                              batch_size=BATCH_SIZE, 
                                              shuffle=True,
                                              class_mode='categorical') 

test_generator = test_aug.flow_from_directory(test_path, 
                                               target_size=(IMG_WIDTH, IMG_HEIGHT), 
                                               batch_size=1, 
                                               shuffle=False,
                                               class_mode=None)
# Out:
# Found 4160 images belonging to 6 classes.
# Found 896 images belonging to 6 classes.
# Found 334 images belonging to 6 classes.

# %% [markdown]
# # Model

# %% [markdown]
# ## Build Model

# %%
def build_model_VGG16():
  base_model = tf.keras.applications.VGG16(include_top=False, input_shape=(IMG_WIDTH, IMG_HEIGHT, 3), weights='imagenet')
  average_pooling_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
  prediction_layer = tf.keras.layers.Dense(units=NUM_CLASSES, activation='softmax', name='prediction')(average_pooling_layer)
  model = Model(inputs=base_model.input, outputs=prediction_layer)
  return model

# %%
model = build_model_VGG16()

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# prediction (Dense)           (None, 6)                 3078
# =================================================================
# Total params: 14,717,766
# Trainable params: 14,717,766
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile

# %%
model.compile(optimizer=Adam(LR), 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Callbacks

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')

model_checkpoint = ModelCheckpoint(filepath='HAM10000_VGG16_Ver2_model.h5', save_best_only=True, monitor='val_loss', mode='min')

reduce_lr_rate = ReduceLROnPlateau(monitor='val_loss', factor=0.3, min_lr=1e-7, patience=10, verbose=1, min_delta=1e-4, mode='min')

# %% [markdown]
# ## Training

# %%
history = model.fit(train_generator,
                    validation_data=val_generator,
                    epochs=EPOCHS,
                    callbacks=[early_stop, model_checkpoint, reduce_lr_rate],
                    verbose=1)
# Out:
# Epoch 1/100
# 130/130 [==============================] - ETA: 0s - batch: 64.5000 - size: 32.0000 - loss: 1.3778 - accuracy: 0.4435
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 130/130 [==============================] - 72s 501ms/step - batch: 64.5000 - size: 32.0000 - loss: 1.3778 - accuracy: 0.4435 - val_loss: 1.1993 - val_accuracy: 0.5078
# Epoch 2/100
# 130/130 [==============================] - 65s 504ms/step - batch: 64.5000 - size: 32.0000 - loss: 1.1071 - accuracy: 0.5599 - val_loss: 1.0305 - val_accuracy: 0.5759
# Epoch 3/100
# 130/130 [==============================] - 65s 502ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.9449 - accuracy: 0.6361 - val_loss: 1.0485 - val_accuracy: 0.6105
# Epoch 4/100
# 130/130 [==============================] - 65s 502ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.8445 - accuracy: 0.6769 - val_loss: 0.8931 - val_accuracy: 0.6596
# Epoch 5/100
# 130/130 [==============================] - 65s 498ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.7620 - accuracy: 0.7063 - val_loss: 0.9643 - val_accuracy: 0.6451
# Epoch 6/100
# 130/130 [==============================] - 65s 500ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.7216 - accuracy: 0.7245 - val_loss: 0.8570 - val_accuracy: 0.6763
# Epoch 7/100
# 130/130 [==============================] - 65s 503ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.6699 - accuracy: 0.7387 - val_loss: 0.8160 - val_accuracy: 0.6931
# Epoch 8/100
# 130/130 [==============================] - 65s 499ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.6346 - accuracy: 0.7541 - val_loss: 0.8256 - val_accuracy: 0.6886
# Epoch 9/100
# 130/130 [==============================] - 65s 501ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.5953 - accuracy: 0.7740 - val_loss: 0.8281 - val_accuracy: 0.6908
# Epoch 10/100
# 130/130 [==============================] - 65s 500ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.5390 - accuracy: 0.7974 - val_loss: 0.8682 - val_accuracy: 0.6998
# Epoch 11/100
# 130/130 [==============================] - 65s 502ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.5272 - accuracy: 0.8026 - val_loss: 0.8118 - val_accuracy: 0.7121
# Epoch 12/100
# 130/130 [==============================] - 65s 502ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.5052 - accuracy: 0.8002 - val_loss: 0.8331 - val_accuracy: 0.6987
# Epoch 13/100
# 130/130 [==============================] - 65s 504ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.4925 - accuracy: 0.8156 - val_loss: 0.7871 - val_accuracy: 0.7310
# Epoch 14/100
# 130/130 [==============================] - 65s 502ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.4701 - accuracy: 0.8195 - val_loss: 0.9988 - val_accuracy: 0.7098
# Epoch 15/100
# 130/130 [==============================] - 65s 500ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.4399 - accuracy: 0.8363 - val_loss: 1.0486 - val_accuracy: 0.6797
# Epoch 16/100
# 130/130 [==============================] - 65s 501ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3970 - accuracy: 0.8452 - val_loss: 0.9013 - val_accuracy: 0.7065
# Epoch 17/100
# 130/130 [==============================] - 66s 506ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.4222 - accuracy: 0.8409 - val_loss: 0.7591 - val_accuracy: 0.7411
# Epoch 18/100
# 130/130 [==============================] - 65s 500ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3706 - accuracy: 0.8531 - val_loss: 0.8532 - val_accuracy: 0.7355
# Epoch 19/100
# 130/130 [==============================] - 65s 502ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3524 - accuracy: 0.8709 - val_loss: 0.7978 - val_accuracy: 0.7344
# Epoch 20/100
# 130/130 [==============================] - 65s 503ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3527 - accuracy: 0.8695 - val_loss: 0.8767 - val_accuracy: 0.7143
# Epoch 21/100
# 130/130 [==============================] - 65s 503ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3158 - accuracy: 0.8834 - val_loss: 0.7962 - val_accuracy: 0.7467
# Epoch 22/100
# 130/130 [==============================] - 65s 503ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.3116 - accuracy: 0.8815 - val_loss: 0.9589 - val_accuracy: 0.7266
# Epoch 23/100
# 130/130 [==============================] - 65s 501ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.2881 - accuracy: 0.8916 - val_loss: 0.8050 - val_accuracy: 0.7600
# Epoch 24/100
# 130/130 [==============================] - 65s 498ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.2658 - accuracy: 0.9050 - val_loss: 1.0938 - val_accuracy: 0.7020
# Epoch 25/100
# 130/130 [==============================] - 65s 500ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.2699 - accuracy: 0.8978 - val_loss: 0.8521 - val_accuracy: 0.7578
# Epoch 26/100
# 130/130 [==============================] - 66s 506ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.2745 - accuracy: 0.8962 - val_loss: 0.8554 - val_accuracy: 0.7232
# Epoch 27/100
# 130/130 [==============================] - ETA: 0s - batch: 64.5000 - size: 32.0000 - loss: 0.2499 - accuracy: 0.9048
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
# 130/130 [==============================] - 66s 506ms/step - batch: 64.5000 - size: 32.0000 - loss: 0.2499 - accuracy: 0.9048 - val_loss: 0.8310 - val_accuracy: 0.7612

# %% [markdown]
# # Training Graph

# %% [markdown]
# ## Accuracy

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('accuracy')
plt.show()

# %% [markdown]
# ## Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('loss')
plt.show()

# %% [markdown]
# # Evaluation

# %%
test_model = tf.keras.models.load_model('/content/HAM10000_VGG16_Ver2_model.h5')

# %%
num_test_files = len(test_generator.filenames)

# %%
test_generator.reset()

# %%
test_labels = test_generator.classes
predictions = test_model.predict(test_generator, steps=num_test_files//test_generator.batch_size)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '

# %% [markdown]
# ## Confusion Matrix

# %% [markdown]
# ### Without Normalize

# %%
cm = confusion_matrix(test_labels, predictions.argmax(axis=1))

classes_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'vasc']

plot_confusion_matrix(cm, classes_names, False)
# Out:
# Confusion matrix, without normalization
# [[15  6  9  0  3  0]
#  [ 3 36  8  1  4  0]
#  [ 5  5 81  0 19  0]
#  [ 2  0  1  7  2  0]
#  [ 4  3 11  0 94  0]
#  [ 0  1  1  0  1 12]]

# %% [markdown]
# ### With Normalize

# %%
plot_confusion_matrix(cm, classes_names, True)
# Out:
# Normalized confusion matrix
# [[0.45454545 0.18181818 0.27272727 0.         0.09090909 0.        ]
#  [0.05769231 0.69230769 0.15384615 0.01923077 0.07692308 0.        ]
#  [0.04545455 0.04545455 0.73636364 0.         0.17272727 0.        ]
#  [0.16666667 0.         0.08333333 0.58333333 0.16666667 0.        ]
#  [0.03571429 0.02678571 0.09821429 0.         0.83928571 0.        ]
#  [0.         0.06666667 0.06666667 0.         0.06666667 0.8       ]]

# %% [markdown]
# ## Classification Report

# %%
y_pred = np.argmax(predictions, axis=1)
print('Confusion Matrix')
print(confusion_matrix(test_labels, y_pred))
print('Classification Report')
print(classification_report(test_labels, y_pred, target_names=classes_names))
# Out:
# Confusion Matrix
# [[15  6  9  0  3  0]
#  [ 3 36  8  1  4  0]
#  [ 5  5 81  0 19  0]
#  [ 2  0  1  7  2  0]
#  [ 4  3 11  0 94  0]
#  [ 0  1  1  0  1 12]]
# Classification Report
#               precision    recall  f1-score   support
#
#        akiec       0.52      0.45      0.48        33
#          bcc       0.71      0.69      0.70        52
#          bkl       0.73      0.74      0.73       110
#           df       0.88      0.58      0.70        12
#          mel       0.76      0.84      0.80       112
#         vasc       1.00      0.80      0.89        15
#
#     accuracy                           0.73       334
#    macro avg       0.77      0.68      0.72       334
# weighted avg       0.73      0.73      0.73       334

# %% [markdown]
# ## TP FP FN TN

# %%
cm_2 = confusion_matrix(test_labels, y_pred)

# %% [markdown]
# ### TP

# %%
TruePositive= np.diag(cm_2)

# %%
print(TruePositive)
sumTruePositive = sum(TruePositive)
print('Sum of True Positive: ', sumTruePositive)
# Out:
# [15 36 81  7 94 12]
# Sum of True Positive:  245

# %% [markdown]
# ### FP

# %%
FalsePositive = []
for i in range(NUM_CLASSES):
    FalsePositive.append(sum(cm_2[:,i]) - cm_2[i,i])

# %%
print(FalsePositive)
sumFalsePositive = sum(FalsePositive)
print('Sum of False Positive: ', sumFalsePositive)
# Out:
# [14, 15, 30, 1, 29, 0]
# Sum of False Positive:  89

# %% [markdown]
# ### FN

# %%
FalseNegative = []
for i in range(NUM_CLASSES):
    FalseNegative.append(sum(cm_2[i,:]) - cm_2[i,i])

# %%
print(FalseNegative)
sumFalseNegative = sum(FalseNegative)
print('Sum of False Negative: ', sumFalseNegative)
# Out:
# [18, 16, 29, 5, 18, 3]
# Sum of False Negative:  89

# %% [markdown]
# ### TN

# %%
TrueNegative = []
for i in range(NUM_CLASSES):
    temp = np.delete(cm_2, i, 0)   # delete ith row
    temp = np.delete(temp, i, 1)  # delete ith column
    TrueNegative.append(sum(sum(temp)))

# %%
print(TrueNegative)
sumTrueNegative = sum(TrueNegative)
print('Sum of True Negative: ', sumTrueNegative)
# Out:
# [287, 267, 194, 321, 193, 319]
# Sum of True Negative:  1581

# %% [markdown]
# ## Check TP + FP + FN + TN = Test set

# %%
l = len(test_labels)
for i in range(NUM_CLASSES):
    print(TruePositive[i] + FalsePositive[i] + FalseNegative[i] + TrueNegative[i] == l)
# Out:
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ## PYCM

# %%
# !pip3 install pycm==3.0
# Out:
# Requirement already satisfied: pycm==3.0 in /usr/local/lib/python3.6/dist-packages (3.0)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pycm==3.0) (1.19.5)
# Requirement already satisfied: art>=1.8 in /usr/local/lib/python3.6/dist-packages (from pycm==3.0) (5.1)

# %%
from pycm import *

# %%
py_cm = ConfusionMatrix(actual_vector=test_labels, predict_vector=y_pred)

# %%
py_cm.classes
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
py_cm.table
# Out:
# {0: {0: 15, 1: 6, 2: 9, 3: 0, 4: 3, 5: 0},
#  1: {0: 3, 1: 36, 2: 8, 3: 1, 4: 4, 5: 0},
#  2: {0: 5, 1: 5, 2: 81, 3: 0, 4: 19, 5: 0},
#  3: {0: 2, 1: 0, 2: 1, 3: 7, 4: 2, 5: 0},
#  4: {0: 4, 1: 3, 2: 11, 3: 0, 4: 94, 5: 0},
#  5: {0: 0, 1: 1, 2: 1, 3: 0, 4: 1, 5: 12}}

# %%
print(py_cm)
# Out:
# Predict  0        1        2        3        4        5
# Actual
# 0        15       6        9        0        3        0
#
# 1        3        36       8        1        4        0
#
# 2        5        5        81       0        19       0
#
# 3        2        0        1        7        2        0
#
# 4        4        3        11       0        94       0
#
# 5        0        1        1        0        1        12
#
#
#
#
#
# Overall Statistics :
#
# 95% CI                                                            (0.68612,0.78095)
# ACC Macro                                                         0.91118
# ARI                                                               0.44548
# AUNP                                                              0.81632
# AUNU                                                              0.81154
# Bangdiwala B                                                      0.57283
# Bennett S                                                         0.68024
# CBA                                                               0.67069
# CSI                                                               0.44965
# Chi-Squared                                                       785.98968
# Chi-Squared DF                                                    25
# Conditional Entropy                                               1.17229
# Cramer V                                                          0.68604
# Cross Entropy                                                     2.1861
# F1 Macro                                                          0.71747
# F1 Micro                                                          0.73353
# FNR Macro                                                         0.31569
# FNR Micro                                                         0.26647
# FPR Macro                                                         0.06123
# FPR Micro                                                         0.05329
# Gwet AC1                                                          0.68784
# Hamming Loss                                                      0.26647
# Joint Entropy                                                     3.34976
# KL Divergence                                                     0.00863
# Kappa                                                             0.63609
# Kappa 95% CI                                                      (0.57134,0.70084)
# Kappa No Prevalence                                               0.46707
# Kappa Standard Error                                              0.03304
# Kappa Unbiased                                                    0.63591
# Krippendorff Alpha                                                0.63645
# Lambda A                                                          0.5991
# Lambda B                                                          0.5782
# Mutual Information                                                0.90811
# NIR                                                               0.33533
# Overall ACC                                                       0.73353
# Overall CEN                                                       0.35111
# Overall J                                                         (3.44016,0.57336)
# Overall MCC                                                       0.63679
# Overall MCEN                                                      0.47491
# Overall RACC                                                      0.26777
# Overall RACCU                                                     0.26813
# P-Value                                                           0.0
# PPV Macro                                                         0.76535
# PPV Micro                                                         0.73353
# Pearson C                                                         0.83772
# Phi-Squared                                                       2.35326
# RCI                                                               0.41705
# RR                                                                55.66667
# Reference Entropy                                                 2.17746
# Response Entropy                                                  2.0804
# SOA1(Landis & Koch)                                               Substantial
# SOA2(Fleiss)                                                      Intermediate to Good
# SOA3(Altman)                                                      Good
# SOA4(Cicchetti)                                                   Good
# SOA5(Cramer)                                                      Strong
# SOA6(Matthews)                                                    Moderate
# Scott PI                                                          0.63591
# Standard Error                                                    0.02419
# TNR Macro                                                         0.93877
# TNR Micro                                                         0.94671
# TPR Macro                                                         0.68431
# TPR Micro                                                         0.73353
# Zero-one Loss                                                     89
#
# Class Statistics :
#
# Classes                                                           0             1             2             3             4             5
# ACC(Accuracy)                                                     0.90419       0.90719       0.82335       0.98204       0.85928       0.99102
# AGF(Adjusted F-score)                                             0.66295       0.81003       0.79929       0.78545       0.86321       0.90946
# AGM(Adjusted geometric mean)                                      0.79824       0.87242       0.82568       0.87759       0.86025       0.946
# AM(Difference between automatic and manual classification)        -4            -1            1             -4            11            -3
# AUC(Area under the ROC curve)                                     0.70402       0.81956       0.80122       0.79011       0.85433       0.9
# AUCI(AUC value interpretation)                                    Good          Very Good     Very Good     Good          Very Good     Excellent
# AUPR(Area under the PR curve)                                     0.48589       0.6991        0.73305       0.72917       0.80176       0.9
# BCD(Bray-Curtis dissimilarity)                                    0.00599       0.0015        0.0015        0.00599       0.01647       0.00449
# BM(Informedness or bookmaker informedness)                        0.40803       0.63912       0.60244       0.58023       0.70866       0.8
# CEN(Confusion entropy)                                            0.56019       0.40523       0.36093       0.3301        0.28684       0.15904
# DOR(Diagnostic odds ratio)                                        17.08333      40.05         18.06207      449.4         34.75479      None
# DP(Discriminant power)                                            0.67955       0.88356       0.69289       1.46247       0.84961       None
# DPI(Discriminant power interpretation)                            Poor          Poor          Poor          Limited       Poor          None
# ERR(Error rate)                                                   0.09581       0.09281       0.17665       0.01796       0.14072       0.00898
# F0.5(F0.5 score)                                                  0.50336       0.70312       0.73105       0.79545       0.77815       0.95238
# F1(F1 score - harmonic mean of precision and sensitivity)         0.48387       0.69903       0.73303       0.7           0.8           0.88889
# F2(F2 score)                                                      0.46584       0.69498       0.73503       0.625         0.82312       0.83333
# FDR(False discovery rate)                                         0.48276       0.29412       0.27027       0.125         0.23577       0.0
# FN(False negative/miss/type 2 error)                              18            16            29            5             18            3
# FNR(Miss rate or false negative rate)                             0.54545       0.30769       0.26364       0.41667       0.16071       0.2
# FOR(False omission rate)                                          0.05902       0.05654       0.13004       0.01534       0.08531       0.00932
# FP(False positive/type 1 error/false alarm)                       14            15            30            1             29            0
# FPR(Fall-out or false positive rate)                              0.04651       0.05319       0.13393       0.00311       0.13063       0.0
# G(G-measure geometric mean of precision and sensitivity)          0.48488       0.69906       0.73304       0.71443       0.80088       0.89443
# GI(Gini index)                                                    0.40803       0.63912       0.60244       0.58023       0.70866       0.8
# GM(G-mean geometric mean of specificity and sensitivity)          0.65833       0.80962       0.79859       0.76258       0.8542        0.89443
# IBA(Index of balanced accuracy)                                   0.21716       0.48866       0.55502       0.34103       0.7077        0.64
# ICSI(Individual classification success index)                     -0.02821      0.39819       0.46609       0.45833       0.60351       0.8
# IS(Information score)                                             2.38822       2.18076       1.14778       4.6061        1.18842       4.47681
# J(Jaccard index)                                                  0.31915       0.53731       0.57857       0.53846       0.66667       0.8
# LS(Lift score)                                                    5.23511       4.53394       2.21572       24.35417      2.27904       22.26667
# MCC(Matthews correlation coefficient)                             0.4324        0.64421       0.60106       0.70626       0.69363       0.89025
# MCCI(Matthews correlation coefficient interpretation)             Weak          Moderate      Moderate      Strong        Moderate      Strong
# MCEN(Modified confusion entropy)                                  0.65707       0.53655       0.4862        0.4215        0.40412       0.23522
# MK(Markedness)                                                    0.45822       0.64935       0.59968       0.85966       0.67892       0.99068
# N(Condition negative)                                             301           282           224           322           222           319
# NLR(Negative likelihood ratio)                                    0.57206       0.32498       0.3044        0.41796       0.18486       0.2
# NLRI(Negative likelihood ratio interpretation)                    Negligible    Poor          Poor          Poor          Fair          Fair
# NPV(Negative predictive value)                                    0.94098       0.94346       0.86996       0.98466       0.91469       0.99068
# OC(Overlap coefficient)                                           0.51724       0.70588       0.73636       0.875         0.83929       1.0
# OOC(Otsuka-Ochiai coefficient)                                    0.48488       0.69906       0.73304       0.71443       0.80088       0.89443
# OP(Optimized precision)                                           0.54984       0.75192       0.74241       0.72033       0.84167       0.87991
# P(Condition positive or support)                                  33            52            110           12            112           15
# PLR(Positive likelihood ratio)                                    9.77273       13.01538      5.49818       187.83333     6.42488       None
# PLRI(Positive likelihood ratio interpretation)                    Fair          Good          Fair          Good          Fair          None
# POP(Population)                                                   334           334           334           334           334           334
# PPV(Precision or positive predictive value)                       0.51724       0.70588       0.72973       0.875         0.76423       1.0
# PRE(Prevalence)                                                   0.0988        0.15569       0.32934       0.03593       0.33533       0.04491
# Q(Yule Q - coefficient of colligation)                            0.8894        0.95128       0.89508       0.99556       0.94406       None
# QI(Yule Q interpretation)                                         Strong        Strong        Strong        Strong        Strong        None
# RACC(Random accuracy)                                             0.00858       0.02377       0.10945       0.00086       0.12349       0.00161
# RACCU(Random accuracy unbiased)                                   0.00861       0.02378       0.10945       0.0009        0.12376       0.00163
# TN(True negative/correct rejection)                               287           267           194           321           193           319
# TNR(Specificity or true negative rate)                            0.95349       0.94681       0.86607       0.99689       0.86937       1.0
# TON(Test outcome negative)                                        305           283           223           326           211           322
# TOP(Test outcome positive)                                        29            51            111           8             123           12
# TP(True positive/hit)                                             15            36            81            7             94            12
# TPR(Sensitivity, recall, hit rate, or true positive rate)         0.45455       0.69231       0.73636       0.58333       0.83929       0.8
# Y(Youden index)                                                   0.40803       0.63912       0.60244       0.58023       0.70866       0.8
# dInd(Distance index)                                              0.54743       0.31226       0.2957        0.41668       0.20711       0.2
# sInd(Similarity index)                                            0.61291       0.7792        0.79091       0.70536       0.85355       0.85858

# %% [markdown]
# ### Average AUC

# %%
AV_AUC = (py_cm.AUC[0] + py_cm.AUC[1] + py_cm.AUC[2] + py_cm.AUC[3] + py_cm.AUC[4] + py_cm.AUC[5])/len(py_cm.AUC)

# %%
print('Average AUC: ', AV_AUC)
# Out:
# Average AUC:  0.8115389934538199

# %% [markdown]
# ### Average Sensitivity

# %%
AV_Sens = (py_cm.TPR[0] + py_cm.TPR[1] + py_cm.TPR[2] + py_cm.TPR[3] + py_cm.TPR[4] + py_cm.TPR[5])/len(py_cm.TPR)

# %%
print('Average Sensitivity: ', AV_Sens)
# Out:
# Average Sensitivity:  0.6843059718059719

# %% [markdown]
# ### Average Specificity

# %%
AV_Spec = (py_cm.TNR[0] + py_cm.TNR[1] + py_cm.TNR[2] + py_cm.TNR[3] + py_cm.TNR[4] + py_cm.TNR[5])/len(py_cm.TNR)

# %%
print('Average Specificity: ', AV_Spec)
# Out:
# Average Specificity:  0.938772015101668

# %% [markdown]
# ## Grad-CAM

# %%
last_conv2d = 'block5_conv3'

# %% [markdown]
# ### AKIEC

# %%
akiec_img = '/content/6_classes_HAM10000_split_Ver2/images/pca-aug_train/akiec/ISIC_0026492.jpg'

# %%
 gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, akiec_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.996
# 	akiec          	(0)	with probability 0.002
# 	bkl            	(2)	with probability 0.001
# 	df             	(3)	with probability 0.000
# 	bcc            	(1)	with probability 0.000
# Explanation for 'mel'

# %% [markdown]
# ### BCC

# %%
bcc_img = '/content/6_classes_HAM10000_split_Ver2/images/pca-aug_train/bcc/ISIC_0024332.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, bcc_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	bcc            	(1)	with probability 0.809
# 	bkl            	(2)	with probability 0.119
# 	mel            	(4)	with probability 0.041
# 	akiec          	(0)	with probability 0.027
# 	df             	(3)	with probability 0.004
# Explanation for 'bcc'

# %% [markdown]
# ### BKL

# %%
bkl_img = '/content/6_classes_HAM10000_split_Ver2/images/pca-aug_train/bkl/ISIC_0025548.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, bkl_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.994
# 	bkl            	(2)	with probability 0.006
# 	akiec          	(0)	with probability 0.000
# 	df             	(3)	with probability 0.000
# 	bcc            	(1)	with probability 0.000
# Explanation for 'mel'

# %% [markdown]
# ### DF

# %%
df_img = '/content/6_classes_HAM10000_split_Ver2/images/cc_val/df/ISIC_0033626.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, df_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.792
# 	df             	(3)	with probability 0.202
# 	akiec          	(0)	with probability 0.005
# 	bkl            	(2)	with probability 0.001
# 	bcc            	(1)	with probability 0.000
# Explanation for 'mel'

# %% [markdown]
# ### MEL

# %%
mel_img = '/content/6_classes_HAM10000_split_Ver2/images/pca-aug_train/mel/ISIC_0024516.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, mel_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	mel            	(4)	with probability 0.999
# 	akiec          	(0)	with probability 0.001
# 	bkl            	(2)	with probability 0.000
# 	df             	(3)	with probability 0.000
# 	bcc            	(1)	with probability 0.000
# Explanation for 'mel'

# %% [markdown]
# ### VASC

# %%
vasc_img = '/content/6_classes_HAM10000_split_Ver2/images/cc_test/vasc/ISIC_0025452.jpg'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, vasc_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	vasc           	(5)	with probability 1.000
# 	mel            	(4)	with probability 0.000
# 	bcc            	(1)	with probability 0.000
# 	df             	(3)	with probability 0.000
# 	akiec          	(0)	with probability 0.000
# Explanation for 'vasc'

# %% [markdown]
# # Download Model

# %%
from google.colab import files

# %%
files.download('/content/HAM10000_VGG16_Ver2_model.h5')
