# %% [markdown]
# <a href="https://colab.research.google.com/github/filmerxyz/JSTP-22_SkinDiseaseClassificationUsingMachineLearning/blob/master/PRACTICE_CIFAR_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**CIFAR-10**

# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import models
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, Dense, MaxPooling2D, Dropout, Activation, Flatten, GlobalAveragePooling2D
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.applications.imagenet_utils import preprocess_input
# from tensorflow.keras.applications.nasnet import decode_predictions
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import regularizers

from tensorflow.keras.datasets import cifar10

from sklearn.metrics import classification_report,confusion_matrix
import itertools

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Parameters

# %%
IMG_WIDTH = 32
IMG_HEIGHT = 32
NUM_CLASSES = 10
BATCH_SIZE = 32
EPOCHS = 50

# %% [markdown]
# # The data, split between train and test sets:

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %% [markdown]
# # See shape

# %%
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
img_rows, img_cols , channels= 32,32,3
for i in range(0,9):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i])
plt.show()

# %% [markdown]
# # Augmentation

# %%
datagen = ImageDataGenerator(rotation_range=360,
                             zoom_range=0.1,
                             width_shift_range=0.1,
                             height_shift_range=0.1,
                             horizontal_flip=True,
                             vertical_flip=True,
                             fill_mode='reflect')
datagen.fit(x_train)

# %%
for X_batch, y_batch in datagen.flow(x_train, y_train, batch_size=9):
    for i in range(0, 9):
        plt.subplot(330 + 1 + i)
        plt.imshow(X_batch[i].astype(np.uint8))
    plt.show()
    break

# %% [markdown]
# # One how encoding

# %%
y_train = tf.keras.utils.to_categorical(y_train, NUM_CLASSES)
y_test = tf.keras.utils.to_categorical(y_test, NUM_CLASSES)

# %%
classes_names = np.unique(y_train)

# %% [markdown]
# # Normalize

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255.
x_test /= 255.

# %% [markdown]
# # Steps

# %%
train_steps_per_epoch = x_train.shape[0] // BATCH_SIZE
val_steps_per_epoch = x_test.shape[0] // BATCH_SIZE

# %% [markdown]
# # Model

# %%
base_model = tf.keras.applications.DenseNet201(include_top=False, weights='imagenet', input_shape=x_train.shape[1:])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 1s 0us/step

# %%
len(base_model.layers)
# Out:
# 707

# %%
# base_model.summary()

# %% [markdown]
# # Fine Tune

# %% [markdown]
# Freeze layer

# %%
# base_model.trainable = False

# %%
# for layer in base_model.layers[:350]:
#   layer.trainable = False

# %%
# base_model.summary()

# %%
average_pooling_layer = GlobalAveragePooling2D()(base_model.output)
dense1 = Dense(1024, activation='relu', kernel_regularizer=regularizers.l2(0.01))(average_pooling_layer)
# dense2 = Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01))(dense1)
dense3 = Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01))(dense1)
dense4 = Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01))(dense3)
dense5 = Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01))(dense4)
dropout1 = Dropout(0.5)(dense5)
prediction_layer = Dense(units=NUM_CLASSES, activation='softmax', name='prediction')(dropout1)
model = tf.keras.models.Model(inputs=base_model.input, outputs=prediction_layer)

# %%
model.compile(optimizer=Adam(lr=9e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# model.summary()

# %% [markdown]
# # Callbacks

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')

model_checkpoint = ModelCheckpoint(filepath='cifar10_model.h5', save_best_only=True, monitor='val_loss', mode='min')

reduce_lr_rate = ReduceLROnPlateau(monitor='val_loss', factor=0.3, min_lr=1e-7, patience=10, verbose=1, min_delta=1e-4, mode='min')

# %%
cb_list = [early_stop, model_checkpoint, reduce_lr_rate]

# %%
history = model.fit(x_train, y_train,
          batch_size=BATCH_SIZE,
          epochs=EPOCHS,
          # validation_data=(x_test, y_test),
          callbacks=cb_list,
          validation_split=0.2,
          shuffle=True)
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 226s 180ms/step - loss: 8.3782 - accuracy: 0.5519 - val_loss: 3.3658 - val_accuracy: 0.7711 - lr: 9.0000e-05
# Epoch 2/50
# 1250/1250 [==============================] - 220s 176ms/step - loss: 2.4309 - accuracy: 0.7669 - val_loss: 1.6203 - val_accuracy: 0.8159 - lr: 9.0000e-05
# Epoch 3/50
# 1250/1250 [==============================] - 220s 176ms/step - loss: 1.4089 - accuracy: 0.8262 - val_loss: 1.1404 - val_accuracy: 0.8382 - lr: 9.0000e-05
# Epoch 4/50
# 1250/1250 [==============================] - 220s 176ms/step - loss: 1.0331 - accuracy: 0.8621 - val_loss: 0.9802 - val_accuracy: 0.8384 - lr: 9.0000e-05
# Epoch 5/50
# 1250/1250 [==============================] - 220s 176ms/step - loss: 0.7939 - accuracy: 0.8971 - val_loss: 0.8609 - val_accuracy: 0.8471 - lr: 9.0000e-05
# Epoch 6/50
# 1250/1250 [==============================] - 219s 176ms/step - loss: 0.6483 - accuracy: 0.9185 - val_loss: 0.8244 - val_accuracy: 0.8474 - lr: 9.0000e-05
# Epoch 7/50
# 1250/1250 [==============================] - 220s 176ms/step - loss: 0.5438 - accuracy: 0.9341 - val_loss: 0.7726 - val_accuracy: 0.8540 - lr: 9.0000e-05
# Epoch 8/50
# 1250/1250 [==============================] - 220s 176ms/step - loss: 0.4645 - accuracy: 0.9461 - val_loss: 0.7370 - val_accuracy: 0.8556 - lr: 9.0000e-05
# Epoch 9/50
# 1250/1250 [==============================] - 220s 176ms/step - loss: 0.4111 - accuracy: 0.9534 - val_loss: 0.7315 - val_accuracy: 0.8505 - lr: 9.0000e-05
# Epoch 10/50
# 1250/1250 [==============================] - 221s 177ms/step - loss: 0.3590 - accuracy: 0.9622 - val_loss: 0.7110 - val_accuracy: 0.8534 - lr: 9.0000e-05
# Epoch 11/50
# 1250/1250 [==============================] - 220s 176ms/step - loss: 0.3341 - accuracy: 0.9660 - val_loss: 0.7298 - val_accuracy: 0.8557 - lr: 9.0000e-05
# Epoch 12/50
# 1250/1250 [==============================] - 220s 176ms/step - loss: 0.3074 - accuracy: 0.9700 - val_loss: 0.7460 - val_accuracy: 0.8466 - lr: 9.0000e-05
# Epoch 13/50
# 1250/1250 [==============================] - 222s 178ms/step - loss: 0.2816 - accuracy: 0.9735 - val_loss: 0.7059 - val_accuracy: 0.8514 - lr: 9.0000e-05
# Epoch 14/50
# 1250/1250 [==============================] - 220s 176ms/step - loss: 0.2723 - accuracy: 0.9743 - val_loss: 0.7100 - val_accuracy: 0.8523 - lr: 9.0000e-05
# Epoch 15/50
# 1250/1250 [==============================] - 219s 175ms/step - loss: 0.2539 - accuracy: 0.9784 - val_loss: 0.7321 - val_accuracy: 0.8425 - lr: 9.0000e-05
# Epoch 16/50
# 1250/1250 [==============================] - 219s 175ms/step - loss: 0.2466 - accuracy: 0.9775 - val_loss: 0.7067 - val_accuracy: 0.8537 - lr: 9.0000e-05
# Epoch 17/50
# 1250/1250 [==============================] - 219s 175ms/step - loss: 0.2340 - accuracy: 0.9797 - val_loss: 0.7200 - val_accuracy: 0.8491 - lr: 9.0000e-05
# Epoch 18/50
# 1250/1250 [==============================] - 222s 178ms/step - loss: 0.2250 - accuracy: 0.9815 - val_loss: 0.6696 - val_accuracy: 0.8611 - lr: 9.0000e-05
# Epoch 19/50
# 1250/1250 [==============================] - 219s 175ms/step - loss: 0.2151 - accuracy: 0.9823 - val_loss: 0.7573 - val_accuracy: 0.8433 - lr: 9.0000e-05
# Epoch 20/50
# 1250/1250 [==============================] - 219s 176ms/step - loss: 0.2092 - accuracy: 0.9834 - val_loss: 0.7225 - val_accuracy: 0.8471 - lr: 9.0000e-05
# Epoch 21/50
# 1250/1250 [==============================] - 220s 176ms/step - loss: 0.2019 - accuracy: 0.9839 - val_loss: 0.6928 - val_accuracy: 0.8518 - lr: 9.0000e-05
# Epoch 22/50
# 1250/1250 [==============================] - 222s 177ms/step - loss: 0.1997 - accuracy: 0.9842 - val_loss: 0.6434 - val_accuracy: 0.8564 - lr: 9.0000e-05
# Epoch 23/50
# 1250/1250 [==============================] - 219s 175ms/step - loss: 0.1974 - accuracy: 0.9835 - val_loss: 0.7041 - val_accuracy: 0.8505 - lr: 9.0000e-05
# Epoch 24/50
# 1250/1250 [==============================] - 219s 175ms/step - loss: 0.1879 - accuracy: 0.9854 - val_loss: 0.6659 - val_accuracy: 0.8570 - lr: 9.0000e-05
# Epoch 25/50
# 1250/1250 [==============================] - 219s 175ms/step - loss: 0.1836 - accuracy: 0.9858 - val_loss: 0.6832 - val_accuracy: 0.8577 - lr: 9.0000e-05
# Epoch 26/50
# 1250/1250 [==============================] - 219s 175ms/step - loss: 0.1811 - accuracy: 0.9856 - val_loss: 0.7122 - val_accuracy: 0.8472 - lr: 9.0000e-05
# Epoch 27/50
# 1250/1250 [==============================] - 219s 175ms/step - loss: 0.1763 - accuracy: 0.9872 - val_loss: 0.6979 - val_accuracy: 0.8520 - lr: 9.0000e-05
# Epoch 28/50
# 1250/1250 [==============================] - 219s 175ms/step - loss: 0.1715 - accuracy: 0.9878 - val_loss: 0.6777 - val_accuracy: 0.8544 - lr: 9.0000e-05
# Epoch 29/50
# 1250/1250 [==============================] - 219s 175ms/step - loss: 0.1716 - accuracy: 0.9874 - val_loss: 0.6862 - val_accuracy: 0.8546 - lr: 9.0000e-05
# Epoch 30/50
# 1250/1250 [==============================] - 218s 175ms/step - loss: 0.1689 - accuracy: 0.9871 - val_loss: 0.7026 - val_accuracy: 0.8453 - lr: 9.0000e-05
# Epoch 31/50
# 1250/1250 [==============================] - 218s 175ms/step - loss: 0.1596 - accuracy: 0.9892 - val_loss: 0.6885 - val_accuracy: 0.8563 - lr: 9.0000e-05
# Epoch 32/50
# 1250/1250 [==============================] - ETA: 0s - loss: 0.1598 - accuracy: 0.9881
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 1250/1250 [==============================] - 219s 175ms/step - loss: 0.1598 - accuracy: 0.9881 - val_loss: 0.6945 - val_accuracy: 0.8541 - lr: 9.0000e-05

# %% [markdown]
# # Graph

# %% [markdown]
# ## Accuracy

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('accuracy')
plt.show()

# %% [markdown]
# ## Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('loss')
plt.show()

# %% [markdown]
# # Scores

# %%
test_model = tf.keras.models.load_model('cifar10_model.h5')

# %%
scores = test_model.evaluate(x_test, y_test, verbose=1)
# Out:
# 313/313 [==============================] - 18s 59ms/step - loss: 0.6604 - accuracy: 0.8565

# %%
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Test loss: 0.6604465842247009
# Test accuracy: 0.8565000295639038

# %% [markdown]
# # Evaluate

# %%
y_pred_probabilities = test_model.predict(x_test)

# %%
y_pred_ans = np.argmax(y_pred_probabilities,axis=1)

# %%
y_test = np.argmax(y_test,axis=1)

# %% [markdown]
# ## Confusion Matrix

# %%
cm = confusion_matrix(y_true=y_test, y_pred=y_pred_ans)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %% [markdown]
# ### Without Normalize

# %%
plot_confusion_matrix(cm, classes_names, False)
# Out:
# Confusion matrix, without normalization
# [[910   9  26  11   2   2   3   6  21  10]
#  [ 10 920   2   3   0   0   0   0  12  53]
#  [ 24   3 833  31  34  29  20  23   2   1]
#  [ 13   6  48 706  49 104  25  28   9  12]
#  [ 10   2  41  25 845  24  10  38   5   0]
#  [ 12   1  27 130  19 771   7  26   2   5]
#  [  9   4  24  47  21  16 870   2   2   5]
#  [ 12   1  11  12  36  40   1 881   1   5]
#  [ 44  12   4   6   2   2   1   0 915  14]
#  [ 19  42   5   5   0   1   0   4  10 914]]

# %% [markdown]
# ### With Normalize

# %%
plot_confusion_matrix(cm, classes_names, True)
# Out:
# Normalized confusion matrix
# [[0.91  0.009 0.026 0.011 0.002 0.002 0.003 0.006 0.021 0.01 ]
#  [0.01  0.92  0.002 0.003 0.    0.    0.    0.    0.012 0.053]
#  [0.024 0.003 0.833 0.031 0.034 0.029 0.02  0.023 0.002 0.001]
#  [0.013 0.006 0.048 0.706 0.049 0.104 0.025 0.028 0.009 0.012]
#  [0.01  0.002 0.041 0.025 0.845 0.024 0.01  0.038 0.005 0.   ]
#  [0.012 0.001 0.027 0.13  0.019 0.771 0.007 0.026 0.002 0.005]
#  [0.009 0.004 0.024 0.047 0.021 0.016 0.87  0.002 0.002 0.005]
#  [0.012 0.001 0.011 0.012 0.036 0.04  0.001 0.881 0.001 0.005]
#  [0.044 0.012 0.004 0.006 0.002 0.002 0.001 0.    0.915 0.014]
#  [0.019 0.042 0.005 0.005 0.    0.001 0.    0.004 0.01  0.914]]

# %%
print('Classification report')
print(classification_report(y_true=y_test, y_pred=y_pred_ans))
# Out:
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88      1000
#            1       0.92      0.92      0.92      1000
#            2       0.82      0.83      0.82      1000
#            3       0.72      0.71      0.71      1000
#            4       0.84      0.84      0.84      1000
#            5       0.78      0.77      0.78      1000
#            6       0.93      0.87      0.90      1000
#            7       0.87      0.88      0.88      1000
#            8       0.93      0.92      0.92      1000
#            9       0.90      0.91      0.91      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000
